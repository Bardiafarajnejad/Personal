# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime

import ConstructPortfolio as cp #this will allow us to modularize the code!
#using "ConstructPortfolio.py" that is stored in the same directory! 
#(not using "ConstructPortfolio.ipynb")
# Out:
# /Users/bardiafarajnejad/Desktop/1st Half MFE/AFP/Final Delivery/MFE Group 16 AFP Code

# %% [markdown]
# # Trading on earnings suprises (when using midpoint) is not super informative... buy days do slighly better than sell days
#
# # Both buy and sell have high SR of 0.8-0.9 (on 20%+ returns) but low IR of 0.2 (on 2% alpha)

# %%
#### Please run the line below once in order to get "data_with_rets.pkl" from "afp_data_sample_1995_onward_v2.csv"
#cp.get_data(flag=True)

data = pd.read_pickle('data_with_rets.pkl')
data
# Out:
#          tradedate   osid symbol                    coname  sector_group  \
# 0         19950103  10032    ACK  Armstrong Holdings Inc             7.0
# 1         19950104  10032    ACK  Armstrong Holdings Inc             7.0
# 2         19950105  10032    ACK  Armstrong Holdings Inc             7.0
# 3         19950106  10032    ACK  Armstrong Holdings Inc             7.0
# 4         19950109  10032    ACK  Armstrong Holdings Inc             7.0
# ...            ...    ...    ...                       ...           ...
# 2912427   20210805  78696   COOK               Traeger Inc           7.0
# 2912428   20210806  78722   WEBR            Weber Inc Cl A           NaN
# 2912429   20210809  78722   WEBR            Weber Inc Cl A           7.0
# 2912430   20210901  78803   FCUV       Focus Universal Inc           NaN
# 2912431   20210902  78803   FCUV       Focus Universal Inc           4.0
#
#            max_dt  previoustradedate  tickssinceipo     alpha  stdev_alpha  \
# 0        19970827         19941230.0           8056  0.010006     0.004670
# 1        19970827         19950103.0           8057 -0.003112     0.004656
# 2        19970827         19950104.0           8058  0.019820     0.005805
# 3        19970827         19950105.0           8059  0.045571     0.009709
# 4        19970827         19950106.0           8060  0.032296     0.010892
# ...           ...                ...            ...       ...          ...
# 2912427  20210805         20210804.0              6  0.047968     0.026349
# 2912428  20210809         20210805.0              2  0.000000     0.000000
# 2912429  20210809         20210806.0              3  0.080042     0.025773
# 2912430  20210902         20210831.0              2  0.000000     0.000000
# 2912431  20210902         20210901.0              3 -0.072293     0.019244
#
#          ...  ret1d_lag  alpha1d_lag  ret5d_lag  alpha5d_lag  ret10d_lag  \
# 0        ...    0.00000    -0.003112   0.176850     0.166677    0.131841
# 1        ...    0.01929     0.019820   0.131835     0.124719    0.125412
# 2        ...    0.04732     0.045571   0.119876     0.112258    0.094651
# 3        ...    0.03313     0.032296   0.069278     0.054748    0.063264
# 4        ...    0.06706     0.063220   0.058317     0.037605    0.020420
# ...      ...        ...          ...        ...          ...         ...
# 2912427  ...        NaN          NaN        NaN          NaN         NaN
# 2912428  ...    0.08190     0.080042        NaN          NaN         NaN
# 2912429  ...        NaN          NaN        NaN          NaN         NaN
# 2912430  ...   -0.07106    -0.072293        NaN          NaN         NaN
# 2912431  ...        NaN          NaN        NaN          NaN         NaN
#
#          alpha10d_lag  ret15d_lag  alpha15d_lag  ret20d_lag  alpha20d_lag
# 0            0.102035    0.144700      0.123317    0.138261      0.106187
# 1            0.099894    0.173638      0.151438    0.144692      0.115932
# 2            0.075155    0.170357      0.145504    0.135652      0.101416
# 3            0.050293    0.096391      0.070299    0.090370      0.047479
# 4            0.006697    0.046651      0.026290    0.072892      0.026535
# ...               ...         ...           ...         ...           ...
# 2912427           NaN         NaN           NaN         NaN           NaN
# 2912428           NaN         NaN           NaN         NaN           NaN
# 2912429           NaN         NaN           NaN         NaN           NaN
# 2912430           NaN         NaN           NaN         NaN           NaN
# 2912431           NaN         NaN           NaN         NaN           NaN
#
# [2912432 rows x 175 columns]

# %% [markdown]
# # Midpoint Analyst Estimate = (epshigha1 + epslowa1) / 2
#
# ### Now, let's trade on earnings suprises!
# ### the times when 'epsa1' > ('epshigha1' + epslowa1) / 2
# ###### Buy when positive suprise, so when df['epsa1'] > df['midpoint']
# ###### Sell when negative suprise, so when df['epsa1'] < df['midpoint']
# ### with 1 day, 1 week, 2 weeks, 3 weeks, and 4 weeks holding period
# ### (AHEAD, not backward... so our ret, ret5d, 10d, 15d, and 20d needs to be forward)
# ### Thus, we will use ret5d_'lag' !!
#
# # Set buy_tomorrow>0 when df['epsa1'] > df['midpoint']
# ### ie earnings falls above MID ESTIMATE!
# # Set Sell_tomorrow>0 when df['epsa1'] < df['midpoint']
# ### ie earnings falls below MID ESTIMATE!

# %%
data['report_date'] = pd.to_datetime(data['reportdate'], format='%Y%m%d', errors='ignore')


data = data.sort_values(['osid', 'tradedate']).reset_index(drop=True).copy()

data = data[data['epsa1'].notna()].reset_index(drop=True).copy()
data = data[data['epshigha1'].notna()].reset_index(drop=True).copy()
data = data[data['epslowa1'].notna()].reset_index(drop=True).copy()
data = data[data['ret10d'].notna()].reset_index(drop=True).copy()
data = data[data['report_date'].notna()].reset_index(drop=True).copy()


data['midpoint'] = (data['epshigha1']+data['epslowa1']) / 2

data['earnings_delta_surprise'] = (data['epsa1']-data['midpoint'])/data['midpoint'] #(Actual - midpoint)/midpoint predicted

data = data[data['earnings_delta_surprise'].notna()].reset_index(drop=True).copy()

data['buy_tomorrow1'] = np.where(data['earnings_delta_surprise']>0.05, 1, 0)
data['sell_tomorrow1'] = np.where(data['earnings_delta_surprise']<-0.05, 1, 0)

data['buy_tomorrow2'] = np.where(data['ret10d'] > 0.025, 1, 0)
data['sell_tomorrow2'] = np.where(data['ret10d'] < -0.025, 1, 0)

data['buy_tomorrow3'] = np.where( (data['date']-data['report_date']).dt.days == 1, 1, 0)
data['sell_tomorrow3'] = np.where( (data['date']-data['report_date']).dt.days == 1 , 1, 0)

data['buy_tomorrow'] = data['buy_tomorrow1'] + data['buy_tomorrow2'] + data['buy_tomorrow3']
data['sell_tomorrow'] = data['sell_tomorrow1'] + data['sell_tomorrow2'] + data['sell_tomorrow3']

data['buy_tomorrow'] = np.where(data['buy_tomorrow']==3, 1, 0)
data['sell_tomorrow'] = np.where(data['sell_tomorrow']==3, 1, 0)



print('Total number of Buys: ',np.count_nonzero(data['buy_tomorrow']))
print('Total number of Sells: ',np.count_nonzero(data['sell_tomorrow']))

print('Unique buy_tomorrow values: ',np.unique(data['buy_tomorrow'])) #there are only 0 or 1 values in 'buy_tomorrow'
print('Unique sell_tomorrow values: ',np.unique(data['sell_tomorrow'])) #there are only 0 or 1 values in 'sell_tomorrow'
# Out:
# Total number of Buys:  1101
# Total number of Sells:  975
# Unique buy_tomorrow values:  [0 1]
# Unique sell_tomorrow values:  [0 1]

# %%
data = cp.trade_on_valid_lags_only(data)
# Out:
# There are  0  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  1101
# Total number of Sells:  975

# %% [markdown]
# # Now we can trade!
# ### Holding period of 1 week, 2 weeks, 3 weeks, and 4 weeks with equal weighted portfolios!
#
# # First, create daily equal weighted portfolio weights and returns (NOT AT THE WEEKLY frequency because that will mess up the implementation of the portfolio!). Problem is:
#
# ##### Think (part 1): 1st signal on Monday- want to buy on Tuesday and hold for 1 week in an equal weighted portfolio
# ##### Think (part 2): 2nd signal on Thursday- want to buy on Friday and hold for 1 week in an equal weighted portfolio
# ##### Think (part 3): Will have overlapping portfolio between 1st and 2nd signal on Friday and on Monday
#
# ## Then, for 1 week, 2 week, 3 week, and 4 week holding periods, we must do the following:
# ##### extend "buy_tomorrow" and "sell_tomorrow" forward for 4 more trading days

# %%
data_smaller,data_smaller5,data_smaller10,data_smaller15,data_smaller20 = cp.pull_signal_forward(data)

data_smaller20 = cp.trade_on_valid_lags_only(data_smaller20)
data_smaller15 = cp.trade_on_valid_lags_only(data_smaller15)
data_smaller10 = cp.trade_on_valid_lags_only(data_smaller10)
data_smaller5 = cp.trade_on_valid_lags_only(data_smaller5)
data_smaller = cp.trade_on_valid_lags_only(data_smaller)
# Out:
# There are  3  problems for buying
#
# There are  2  problems for selling
# Total number of Buys:  21884
# Total number of Sells:  19411
#
# There are  3  problems for buying
#
# There are  1  problems for selling
# Total number of Buys:  16435
# Total number of Sells:  14586
#
# There are  2  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  10968
# Total number of Sells:  9740
#
# There are  2  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  5493
# Total number of Sells:  4875
#
# There are  0  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  1100
# Total number of Sells:  975

# %% [markdown]
# # First, do 1 day holding period: data_smaller
# # Next, do 5 day holding period: data_smaller5
# # Next, do 10 day holding period: data_smaller10
# # Next, do 15 day holding period: data_smaller15
# # Next, do 20 day holding period: data_smaller20

# %%
# 1 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.3642
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):              0.902
# Time:                        18:52:17   Log-Likelihood:                 1558.7
# No. Observations:                 771   AIC:                            -3103.
# Df Residuals:                     764   BIC:                            -3071.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0012      0.002     -0.584      0.559      -0.005       0.003
# Mkt-RF        -0.0604      0.126     -0.478      0.633      -0.309       0.188
# SMB            0.0946      0.205      0.461      0.645      -0.308       0.497
# HML           -0.0129      0.192     -0.067      0.947      -0.390       0.364
# RMW           -0.0841      0.263     -0.320      0.749      -0.601       0.433
# CMA           -0.3140      0.359     -0.876      0.381      -1.018       0.390
# MOM            0.3401      0.436      0.780      0.436      -0.516       1.196
# ==============================================================================
# Omnibus:                       70.855   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              366.097
# Skew:                          -0.194   Prob(JB):                     3.18e-80
# Kurtosis:                       6.353   Cond. No.                         379.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     3.553
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):            0.00179
# Time:                        18:52:17   Log-Likelihood:                 1278.5
# No. Observations:                 694   AIC:                            -2543.
# Df Residuals:                     687   BIC:                            -2511.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.003      0.448      0.655      -0.004       0.006
# Mkt-RF         0.4558      0.108      4.240      0.000       0.245       0.667
# SMB            0.0495      0.225      0.220      0.826      -0.393       0.492
# HML           -0.3922      0.215     -1.824      0.069      -0.814       0.030
# RMW           -0.0096      0.297     -0.032      0.974      -0.593       0.574
# CMA            0.2721      0.368      0.740      0.459      -0.450       0.994
# MOM           -0.2772      0.541     -0.512      0.609      -1.340       0.786
# ==============================================================================
# Omnibus:                      111.916   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              775.355
# Skew:                           0.504   Prob(JB):                    4.30e-169
# Kurtosis:                       8.079   Cond. No.                         371.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  770  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  0
#
# There are  674  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  0
# Number of buy periods 771
# Check number of buy periods 771
# Number of sell periods 694
# Check number of sell periods 694
# Summary Statistics:
#
#                                             Buy   Sell
#
# Ann. Mean Alpha (without T-costs)        -19.87 -16.00
# Ann. Tracking Error                       46.41  53.33
# Ann. Information Ratio (without T-costs)  -0.43  -0.30
# Skewness of Alpha                         -0.27   0.68
# --------------------------                   --     --
# Ann. Mean Return (without T-costs)         5.52   4.10
# Ann. Volatility                           50.97  61.85
# Ann. Sharpe Ratio (without T-costs)        0.11   0.07
# Skewness of Return                        -0.19   0.86
# Average Turnover                           1.00   1.00
# T-costs (on 1 unit of capital)             0.44   0.42

# %%
# 5 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller5)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.796
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0960
# Time:                        18:52:39   Log-Likelihood:                 5179.7
# No. Observations:                2367   AIC:                        -1.035e+04
# Df Residuals:                    2360   BIC:                        -1.031e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.001     -0.788      0.431      -0.003       0.001
# Mkt-RF        -0.0950      0.055     -1.730      0.084      -0.203       0.013
# SMB            0.1653      0.099      1.677      0.094      -0.028       0.359
# HML            0.0411      0.092      0.445      0.656      -0.140       0.222
# RMW            0.0199      0.124      0.160      0.873      -0.223       0.263
# CMA           -0.2338      0.166     -1.408      0.159      -0.559       0.092
# MOM            0.4073      0.207      1.970      0.049       0.002       0.813
# ==============================================================================
# Omnibus:                      411.599   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2876.515
# Skew:                           0.632   Prob(JB):                         0.00
# Kurtosis:                       8.251   Cond. No.                         371.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.685
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):              0.121
# Time:                        18:52:39   Log-Likelihood:                 4519.9
# No. Observations:                2192   AIC:                            -9026.
# Df Residuals:                    2185   BIC:                            -8986.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.001      0.885      0.376      -0.001       0.003
# Mkt-RF         0.0328      0.053      0.626      0.532      -0.070       0.136
# SMB            0.2552      0.104      2.453      0.014       0.051       0.459
# HML           -0.1059      0.098     -1.082      0.279      -0.298       0.086
# RMW            0.0295      0.140      0.211      0.833      -0.244       0.303
# CMA           -0.1800      0.178     -1.010      0.313      -0.530       0.169
# MOM           -0.1253      0.245     -0.512      0.609      -0.605       0.354
# ==============================================================================
# Omnibus:                      380.924   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2077.726
# Skew:                           0.707   Prob(JB):                         0.00
# Kurtosis:                       7.555   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  771  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  1993
#
# There are  676  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  1831
# Number of buy periods 2367
# Check number of buy periods 2367
# Number of sell periods 2192
# Check number of sell periods 2192
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         4.64 -3.18
# Ann. Tracking Error                      36.23 40.15
# Ann. Information Ratio (without T-costs)  0.13 -0.08
# Skewness of Alpha                         0.30  0.49
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       21.54 14.73
# Ann. Volatility                          43.16 48.98
# Ann. Sharpe Ratio (without T-costs)       0.50  0.30
# Skewness of Return                        0.65  0.72
# Average Turnover                          0.32  0.31
# T-costs (on 1 unit of capital)            0.72  0.50

# %%
# 10 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller10)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.423
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):              0.202
# Time:                        18:53:06   Log-Likelihood:                 7514.0
# No. Observations:                3351   AIC:                        -1.501e+04
# Df Residuals:                    3344   BIC:                        -1.497e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.001     -0.305      0.761      -0.002       0.001
# Mkt-RF        -0.0338      0.044     -0.772      0.440      -0.120       0.052
# SMB            0.0377      0.077      0.489      0.625      -0.114       0.189
# HML           -0.0079      0.075     -0.106      0.916      -0.155       0.139
# RMW           -0.0417      0.101     -0.415      0.678      -0.239       0.155
# CMA           -0.1259      0.134     -0.938      0.348      -0.389       0.137
# MOM            0.4139      0.164      2.526      0.012       0.093       0.735
# ==============================================================================
# Omnibus:                      654.509   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4754.605
# Skew:                           0.733   Prob(JB):                         0.00
# Kurtosis:                       8.648   Cond. No.                         369.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     2.466
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0221
# Time:                        18:53:06   Log-Likelihood:                 6689.9
# No. Observations:                3161   AIC:                        -1.337e+04
# Df Residuals:                    3154   BIC:                        -1.332e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.001      0.813      0.417      -0.001       0.003
# Mkt-RF        -0.0729      0.042     -1.734      0.083      -0.155       0.010
# SMB            0.1975      0.084      2.357      0.018       0.033       0.362
# HML           -0.1258      0.079     -1.590      0.112      -0.281       0.029
# RMW            0.0671      0.112      0.598      0.550      -0.153       0.287
# CMA           -0.2110      0.145     -1.457      0.145      -0.495       0.073
# MOM           -0.0157      0.193     -0.081      0.935      -0.394       0.363
# ==============================================================================
# Omnibus:                      835.184   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10848.004
# Skew:                           0.883   Prob(JB):                         0.00
# Kurtosis:                      11.902   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  772  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  3081
#
# There are  677  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  2903
# Number of buy periods 3351
# Check number of buy periods 3351
# Number of sell periods 3161
# Check number of sell periods 3161
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        17.81 -0.25
# Ann. Tracking Error                      33.29 36.36
# Ann. Information Ratio (without T-costs)  0.53 -0.01
# Skewness of Alpha                         0.57  0.46
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       35.11 18.52
# Ann. Volatility                          40.85 46.39
# Ann. Sharpe Ratio (without T-costs)       0.86  0.40
# Skewness of Return                        0.75  0.87
# Average Turnover                          0.21  0.21
# T-costs (on 1 unit of capital)            3.29  0.88

# %%
# 15 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller15)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.643
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):              0.131
# Time:                        18:53:34   Log-Likelihood:                 8963.8
# No. Observations:                4074   AIC:                        -1.791e+04
# Df Residuals:                    4067   BIC:                        -1.787e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.212      0.832      -0.001       0.002
# Mkt-RF        -0.0267      0.041     -0.656      0.512      -0.107       0.053
# SMB            0.1101      0.074      1.490      0.136      -0.035       0.255
# HML           -0.0620      0.070     -0.886      0.376      -0.199       0.075
# RMW            0.0056      0.095      0.060      0.953      -0.180       0.191
# CMA           -0.1402      0.124     -1.129      0.259      -0.384       0.103
# MOM            0.3229      0.155      2.077      0.038       0.018       0.628
# ==============================================================================
# Omnibus:                     1769.118   Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            61687.439
# Skew:                           1.411   Prob(JB):                         0.00
# Kurtosis:                      21.853   Cond. No.                         370.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     3.830
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           0.000822
# Time:                        18:53:34   Log-Likelihood:                 8298.7
# No. Observations:                3869   AIC:                        -1.658e+04
# Df Residuals:                    3862   BIC:                        -1.654e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.001      1.108      0.268      -0.001       0.002
# Mkt-RF        -0.0599      0.039     -1.552      0.121      -0.136       0.016
# SMB            0.2385      0.075      3.187      0.001       0.092       0.385
# HML           -0.1004      0.071     -1.411      0.158      -0.240       0.039
# RMW           -0.0575      0.100     -0.574      0.566      -0.254       0.139
# CMA           -0.2627      0.130     -2.024      0.043      -0.517      -0.008
# MOM            0.0465      0.170      0.274      0.784      -0.286       0.379
# ==============================================================================
# Omnibus:                      970.123   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9316.283
# Skew:                           0.915   Prob(JB):                         0.00
# Kurtosis:                      10.379   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  774  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  3845
#
# There are  678  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  3650
# Number of buy periods 4074
# Check number of buy periods 4074
# Number of sell periods 3869
# Check number of sell periods 3869
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        18.50  3.90
# Ann. Tracking Error                      34.55 35.35
# Ann. Information Ratio (without T-costs)  0.54  0.11
# Skewness of Alpha                         1.14  1.09
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       36.40 27.63
# Ann. Volatility                          42.60 45.11
# Ann. Sharpe Ratio (without T-costs)       0.85  0.61
# Skewness of Return                        1.41  0.93
# Average Turnover                          0.17  0.16
# T-costs (on 1 unit of capital)            5.89  2.03

# %%
# 20 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller20)
# Out:
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.591
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0165
# Time:                        18:53:58   Log-Likelihood:                 10207.
# No. Observations:                4597   AIC:                        -2.040e+04
# Df Residuals:                    4590   BIC:                        -2.035e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.001      0.399      0.690      -0.001       0.002
# Mkt-RF        -0.0801      0.037     -2.178      0.029      -0.152      -0.008
# SMB            0.0598      0.067      0.886      0.375      -0.072       0.192
# HML           -0.1336      0.063     -2.119      0.034      -0.257      -0.010
# RMW            0.0112      0.087      0.128      0.898      -0.160       0.183
# CMA            0.0272      0.114      0.240      0.810      -0.195       0.250
# MOM            0.2416      0.144      1.679      0.093      -0.040       0.524
# ==============================================================================
# Omnibus:                     1392.114   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            89069.840
# Skew:                           0.581   Prob(JB):                         0.00
# Kurtosis:                      24.533   Cond. No.                         371.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.934
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           4.85e-05
# Time:                        18:53:58   Log-Likelihood:                 9631.8
# No. Observations:                4428   AIC:                        -1.925e+04
# Df Residuals:                    4421   BIC:                        -1.920e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.001      1.445      0.149      -0.000       0.002
# Mkt-RF        -0.0537      0.036     -1.505      0.133      -0.124       0.016
# SMB            0.2837      0.069      4.120      0.000       0.149       0.419
# HML           -0.0802      0.065     -1.224      0.221      -0.209       0.048
# RMW            0.0015      0.091      0.017      0.987      -0.176       0.179
# CMA           -0.2964      0.119     -2.496      0.013      -0.529      -0.064
# MOM           -0.0556      0.154     -0.362      0.717      -0.357       0.245
# ==============================================================================
# Omnibus:                     1057.805   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10252.266
# Skew:                           0.858   Prob(JB):                         0.00
# Kurtosis:                      10.254   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  773  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  4419
#
# There are  683  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  4236
# Number of buy periods 4597
# Check number of buy periods 4597
# Number of sell periods 4428
# Check number of sell periods 4428
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        12.14  0.42
# Ann. Tracking Error                      33.59 33.82
# Ann. Information Ratio (without T-costs)  0.36  0.01
# Skewness of Alpha                        -0.46  1.09
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       30.89 22.10
# Ann. Volatility                          41.78 43.78
# Ann. Sharpe Ratio (without T-costs)       0.74  0.50
# Skewness of Return                        0.58  0.87
# Average Turnover                          0.14  0.14
# T-costs (on 1 unit of capital)            7.42  1.15
