# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime

import ConstructPortfolio as cp #this will allow us to modularize the code!
#using "ConstructPortfolio.py" that is stored in the same directory! 
#(not using "ConstructPortfolio.ipynb")
# Out:
# /Users/bardiafarajnejad/Desktop/1st Half MFE/AFP/Final Delivery/MFE Group 16 AFP Code

# %% [markdown]
# # Trading on earnings suprises (when using midpoint) is not super informative... buy days do slighly better than sell days
#
# # Both buy and sell have high SR of 0.8-0.9 (on 20%+ returns) but low IR of 0.2 (on 2% alpha)

# %%
#### Please run the line below once in order to get "data_with_rets.pkl" from "afp_data_sample_1995_onward_v2.csv"
#cp.get_data(flag=True)

data = pd.read_pickle('data_with_rets.pkl')
data
# Out:
#          tradedate   osid symbol                    coname  sector_group  \
# 0         19950103  10032    ACK  Armstrong Holdings Inc             7.0
# 1         19950104  10032    ACK  Armstrong Holdings Inc             7.0
# 2         19950105  10032    ACK  Armstrong Holdings Inc             7.0
# 3         19950106  10032    ACK  Armstrong Holdings Inc             7.0
# 4         19950109  10032    ACK  Armstrong Holdings Inc             7.0
# ...            ...    ...    ...                       ...           ...
# 2912427   20210805  78696   COOK               Traeger Inc           7.0
# 2912428   20210806  78722   WEBR            Weber Inc Cl A           NaN
# 2912429   20210809  78722   WEBR            Weber Inc Cl A           7.0
# 2912430   20210901  78803   FCUV       Focus Universal Inc           NaN
# 2912431   20210902  78803   FCUV       Focus Universal Inc           4.0
#
#            max_dt  previoustradedate  tickssinceipo     alpha  stdev_alpha  \
# 0        19970827         19941230.0           8056  0.010006     0.004670
# 1        19970827         19950103.0           8057 -0.003112     0.004656
# 2        19970827         19950104.0           8058  0.019820     0.005805
# 3        19970827         19950105.0           8059  0.045571     0.009709
# 4        19970827         19950106.0           8060  0.032296     0.010892
# ...           ...                ...            ...       ...          ...
# 2912427  20210805         20210804.0              6  0.047968     0.026349
# 2912428  20210809         20210805.0              2  0.000000     0.000000
# 2912429  20210809         20210806.0              3  0.080042     0.025773
# 2912430  20210902         20210831.0              2  0.000000     0.000000
# 2912431  20210902         20210901.0              3 -0.072293     0.019244
#
#          ...  ret1d_lag  alpha1d_lag  ret5d_lag  alpha5d_lag  ret10d_lag  \
# 0        ...    0.00000    -0.003112   0.176850     0.166677    0.131841
# 1        ...    0.01929     0.019820   0.131835     0.124719    0.125412
# 2        ...    0.04732     0.045571   0.119876     0.112258    0.094651
# 3        ...    0.03313     0.032296   0.069278     0.054748    0.063264
# 4        ...    0.06706     0.063220   0.058317     0.037605    0.020420
# ...      ...        ...          ...        ...          ...         ...
# 2912427  ...        NaN          NaN        NaN          NaN         NaN
# 2912428  ...    0.08190     0.080042        NaN          NaN         NaN
# 2912429  ...        NaN          NaN        NaN          NaN         NaN
# 2912430  ...   -0.07106    -0.072293        NaN          NaN         NaN
# 2912431  ...        NaN          NaN        NaN          NaN         NaN
#
#          alpha10d_lag  ret15d_lag  alpha15d_lag  ret20d_lag  alpha20d_lag
# 0            0.102035    0.144700      0.123317    0.138261      0.106187
# 1            0.099894    0.173638      0.151438    0.144692      0.115932
# 2            0.075155    0.170357      0.145504    0.135652      0.101416
# 3            0.050293    0.096391      0.070299    0.090370      0.047479
# 4            0.006697    0.046651      0.026290    0.072892      0.026535
# ...               ...         ...           ...         ...           ...
# 2912427           NaN         NaN           NaN         NaN           NaN
# 2912428           NaN         NaN           NaN         NaN           NaN
# 2912429           NaN         NaN           NaN         NaN           NaN
# 2912430           NaN         NaN           NaN         NaN           NaN
# 2912431           NaN         NaN           NaN         NaN           NaN
#
# [2912432 rows x 175 columns]

# %% [markdown]
# # Midpoint Analyst Estimate = (epshigha1 + epslowa1) / 2
#
# ### Now, let's trade on earnings suprises!
# ### the times when 'epsa1' > ('epshigha1' + epslowa1) / 2
# ###### Buy when positive suprise, so when df['epsa1'] > df['midpoint']
# ###### Sell when negative suprise, so when df['epsa1'] < df['midpoint']
# ### with 1 day, 1 week, 2 weeks, 3 weeks, and 4 weeks holding period
# ### (AHEAD, not backward... so our ret, ret5d, 10d, 15d, and 20d needs to be forward)
# ### Thus, we will use ret5d_'lag' !!
#
# # Set buy_tomorrow>0 when df['epsa1'] > df['midpoint']
# ### ie earnings falls above MID ESTIMATE!
# # Set Sell_tomorrow>0 when df['epsa1'] < df['midpoint']
# ### ie earnings falls below MID ESTIMATE!

# %%
data['report_date'] = pd.to_datetime(data['reportdate'], format='%Y%m%d', errors='ignore')


data = data.sort_values(['osid', 'tradedate']).reset_index(drop=True).copy()

data = data[data['epsa1'].notna()].reset_index(drop=True).copy()
data = data[data['epshigha1'].notna()].reset_index(drop=True).copy()
data = data[data['epslowa1'].notna()].reset_index(drop=True).copy()
data = data[data['report_date'].notna()].reset_index(drop=True).copy()

data['midpoint'] = (data['epshigha1']+data['epslowa1']) / 2

data['earnings_delta_surprise'] = (data['epsa1']-data['midpoint'])/data['midpoint'] #(Actual - midpoint)/midpoint predicted

data = data[data['earnings_delta_surprise'].notna()].reset_index(drop=True).copy()

data['buy_tomorrow1'] = np.where(data['earnings_delta_surprise']>0.05, 1, 0)
data['sell_tomorrow1'] = np.where(data['earnings_delta_surprise']<-0.05, 1, 0)

data['buy_tomorrow2'] = np.where( (data['date']-data['report_date']).dt.days == 1, 1, 0)
data['sell_tomorrow2'] = np.where( (data['date']-data['report_date']).dt.days == 1 , 1, 0)

data['buy_tomorrow'] = data['buy_tomorrow1'] + data['buy_tomorrow2']
data['sell_tomorrow'] = data['sell_tomorrow1'] + data['sell_tomorrow2']

data['buy_tomorrow'] = np.where(data['buy_tomorrow']==2, 1, 0)
data['sell_tomorrow'] = np.where(data['sell_tomorrow']==2, 1, 0)



print('Total number of Buys: ',np.count_nonzero(data['buy_tomorrow']))
print('Total number of Sells: ',np.count_nonzero(data['sell_tomorrow']))

print('Unique buy_tomorrow values: ',np.unique(data['buy_tomorrow'])) #there are only 0 or 1 values in 'buy_tomorrow'
print('Unique sell_tomorrow values: ',np.unique(data['sell_tomorrow'])) #there are only 0 or 1 values in 'sell_tomorrow'
# Out:
# Total number of Buys:  2247
# Total number of Sells:  2582
# Unique buy_tomorrow values:  [0 1]
# Unique sell_tomorrow values:  [0 1]

# %%
data = cp.trade_on_valid_lags_only(data)
# Out:
# There are  0  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  2247
# Total number of Sells:  2582

# %% [markdown]
# # Now we can trade!
# ### Holding period of 1 week, 2 weeks, 3 weeks, and 4 weeks with equal weighted portfolios!
#
# # First, create daily equal weighted portfolio weights and returns (NOT AT THE WEEKLY frequency because that will mess up the implementation of the portfolio!). Problem is:
#
# ##### Think (part 1): 1st signal on Monday- want to buy on Tuesday and hold for 1 week in an equal weighted portfolio
# ##### Think (part 2): 2nd signal on Thursday- want to buy on Friday and hold for 1 week in an equal weighted portfolio
# ##### Think (part 3): Will have overlapping portfolio between 1st and 2nd signal on Friday and on Monday
#
# ## Then, for 1 week, 2 week, 3 week, and 4 week holding periods, we must do the following:
# ##### extend "buy_tomorrow" and "sell_tomorrow" forward for 4 more trading days

# %%
data_smaller,data_smaller5,data_smaller10,data_smaller15,data_smaller20 = cp.pull_signal_forward(data)

data_smaller20 = cp.trade_on_valid_lags_only(data_smaller20)
data_smaller15 = cp.trade_on_valid_lags_only(data_smaller15)
data_smaller10 = cp.trade_on_valid_lags_only(data_smaller10)
data_smaller5 = cp.trade_on_valid_lags_only(data_smaller5)
data_smaller = cp.trade_on_valid_lags_only(data_smaller)
# Out:
# There are  4  problems for buying
#
# There are  4  problems for selling
# Total number of Buys:  44707
# Total number of Sells:  51288
#
# There are  4  problems for buying
#
# There are  3  problems for selling
# Total number of Buys:  33576
# Total number of Sells:  38536
#
# There are  2  problems for buying
#
# There are  2  problems for selling
# Total number of Buys:  22405
# Total number of Sells:  25733
#
# There are  2  problems for buying
#
# There are  2  problems for selling
# Total number of Buys:  11217
# Total number of Sells:  12881
#
# There are  0  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  2245
# Total number of Sells:  2578

# %% [markdown]
# # First, do 1 day holding period: data_smaller
# # Next, do 5 day holding period: data_smaller5
# # Next, do 10 day holding period: data_smaller10
# # Next, do 15 day holding period: data_smaller15
# # Next, do 20 day holding period: data_smaller20

# %%
# 1 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.803
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0950
# Time:                        20:23:48   Log-Likelihood:                 2537.4
# No. Observations:                1301   AIC:                            -5061.
# Df Residuals:                    1294   BIC:                            -5025.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0033      0.002     -1.962      0.050      -0.007   -1.06e-06
# Mkt-RF        -0.1699      0.086     -1.984      0.047      -0.338      -0.002
# SMB            0.1437      0.162      0.889      0.374      -0.173       0.461
# HML           -0.1596      0.149     -1.074      0.283      -0.451       0.132
# RMW            0.1579      0.208      0.759      0.448      -0.250       0.566
# CMA           -0.2012      0.275     -0.733      0.464      -0.740       0.337
# MOM            0.5174      0.355      1.458      0.145      -0.179       1.214
# ==============================================================================
# Omnibus:                      182.620   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2036.944
# Skew:                           0.193   Prob(JB):                         0.00
# Kurtosis:                       9.118   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     4.500
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           0.000159
# Time:                        20:23:48   Log-Likelihood:                 2701.1
# No. Observations:                1402   AIC:                            -5388.
# Df Residuals:                    1395   BIC:                            -5351.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.002      0.696      0.487      -0.002       0.004
# Mkt-RF         0.3690      0.081      4.577      0.000       0.211       0.527
# SMB            0.1031      0.153      0.675      0.500      -0.197       0.403
# HML           -0.2097      0.149     -1.405      0.160      -0.503       0.083
# RMW           -0.0863      0.199     -0.433      0.665      -0.477       0.305
# CMA            0.1218      0.251      0.485      0.628      -0.371       0.615
# MOM           -0.1396      0.347     -0.402      0.688      -0.821       0.541
# ==============================================================================
# Omnibus:                      294.152   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2179.470
# Skew:                           0.769   Prob(JB):                         0.00
# Kurtosis:                       8.911   Cond. No.                         368.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  1868  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  0
#
# There are  2194  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  0
# Number of buy periods 1301
# Check number of buy periods 1301
# Number of sell periods 1402
# Check number of sell periods 1402
# Summary Statistics:
#
#                                             Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        -55.04  0.87
# Ann. Tracking Error                       47.70 49.12
# Ann. Information Ratio (without T-costs)  -1.15  0.02
# Skewness of Alpha                          0.19  0.72
# --------------------------                   --    --
# Ann. Mean Return (without T-costs)       -29.76 26.42
# Ann. Volatility                           54.88 56.51
# Ann. Sharpe Ratio (without T-costs)       -0.54  0.47
# Skewness of Return                         0.25  0.91
# Average Turnover                           1.00  1.00
# T-costs (on 1 unit of capital)             0.29  1.74

# %%
# 5 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller5)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     4.581
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           0.000122
# Time:                        20:24:05   Log-Likelihood:                 7382.6
# No. Observations:                3443   AIC:                        -1.475e+04
# Df Residuals:                    3436   BIC:                        -1.471e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.001     -0.200      0.841      -0.002       0.001
# Mkt-RF        -0.1941      0.042     -4.596      0.000      -0.277      -0.111
# SMB            0.1654      0.081      2.051      0.040       0.007       0.324
# HML           -0.0139      0.077     -0.180      0.857      -0.165       0.137
# RMW           -0.0073      0.105     -0.069      0.945      -0.214       0.199
# CMA           -0.1981      0.138     -1.434      0.152      -0.469       0.073
# MOM            0.1554      0.179      0.869      0.385      -0.195       0.506
# ==============================================================================
# Omnibus:                      694.015   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7620.881
# Skew:                           0.634   Prob(JB):                         0.00
# Kurtosis:                      10.178   Cond. No.                         370.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.272
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0342
# Time:                        20:24:05   Log-Likelihood:                 7761.9
# No. Observations:                3586   AIC:                        -1.551e+04
# Df Residuals:                    3579   BIC:                        -1.547e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.483e-05      0.001      0.069      0.945      -0.002       0.002
# Mkt-RF        -0.0023      0.040     -0.057      0.955      -0.081       0.077
# SMB            0.1623      0.077      2.109      0.035       0.011       0.313
# HML           -0.1379      0.072     -1.902      0.057      -0.280       0.004
# RMW            0.1604      0.101      1.587      0.113      -0.038       0.359
# CMA           -0.1448      0.130     -1.114      0.265      -0.400       0.110
# MOM            0.2659      0.172      1.543      0.123      -0.072       0.604
# ==============================================================================
# Omnibus:                      665.698   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4601.450
# Skew:                           0.702   Prob(JB):                         0.00
# Kurtosis:                       8.369   Cond. No.                         371.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  1870  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  2975
#
# There are  2197  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  3105
# Number of buy periods 3443
# Check number of buy periods 3443
# Number of sell periods 3586
# Check number of sell periods 3586
# Summary Statistics:
#
#                                             Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        -10.42 10.41
# Ann. Tracking Error                       36.52 35.18
# Ann. Information Ratio (without T-costs)  -0.29  0.30
# Skewness of Alpha                          0.65  0.60
# --------------------------                   --    --
# Ann. Mean Return (without T-costs)        11.21 29.19
# Ann. Volatility                           45.19 44.19
# Ann. Sharpe Ratio (without T-costs)        0.25  0.66
# Skewness of Return                         0.69  0.73
# Average Turnover                           0.33  0.33
# T-costs (on 1 unit of capital)             1.04  2.80

# %%
# 10 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller10)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.740
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           8.04e-05
# Time:                        20:24:20   Log-Likelihood:                 10092.
# No. Observations:                4473   AIC:                        -2.017e+04
# Df Residuals:                    4466   BIC:                        -2.013e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.001     -1.183      0.237      -0.002       0.001
# Mkt-RF        -0.1273      0.034     -3.787      0.000      -0.193      -0.061
# SMB            0.1293      0.063      2.061      0.039       0.006       0.252
# HML           -0.0601      0.061     -0.988      0.323      -0.179       0.059
# RMW           -0.0504      0.084     -0.603      0.546      -0.214       0.113
# CMA           -0.1030      0.108     -0.949      0.343      -0.316       0.110
# MOM            0.3706      0.141      2.636      0.008       0.095       0.646
# ==============================================================================
# Omnibus:                      615.119   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6640.840
# Skew:                           0.261   Prob(JB):                         0.00
# Kurtosis:                       8.946   Cond. No.                         371.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.179
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0421
# Time:                        20:24:20   Log-Likelihood:                 10347.
# No. Observations:                4701   AIC:                        -2.068e+04
# Df Residuals:                    4694   BIC:                        -2.063e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.001     -0.252      0.801      -0.001       0.001
# Mkt-RF        -0.0205      0.034     -0.599      0.549      -0.087       0.046
# SMB            0.0653      0.065      1.011      0.312      -0.061       0.192
# HML           -0.1194      0.061     -1.952      0.051      -0.239       0.000
# RMW            0.0706      0.085      0.826      0.409      -0.097       0.238
# CMA           -0.1026      0.110     -0.929      0.353      -0.319       0.114
# MOM            0.3001      0.145      2.071      0.038       0.016       0.584
# ==============================================================================
# Omnibus:                      732.005   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6654.411
# Skew:                           0.460   Prob(JB):                         0.00
# Kurtosis:                       8.755   Cond. No.                         371.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  1873  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  4176
#
# There are  2200  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  4375
# Number of buy periods 4473
# Check number of buy periods 4473
# Number of sell periods 4701
# Check number of sell periods 4701
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        -5.73  5.43
# Ann. Tracking Error                      30.74 32.36
# Ann. Information Ratio (without T-costs) -0.19  0.17
# Skewness of Alpha                         0.33  0.33
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       16.44 25.72
# Ann. Volatility                          40.36 42.58
# Ann. Sharpe Ratio (without T-costs)       0.41  0.60
# Skewness of Return                        0.30  0.47
# Average Turnover                          0.22  0.22
# T-costs (on 1 unit of capital)            1.39  3.03

# %%
# 15 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller15)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     4.045
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           0.000475
# Time:                        20:24:33   Log-Likelihood:                 11688.
# No. Observations:                5099   AIC:                        -2.336e+04
# Df Residuals:                    5092   BIC:                        -2.332e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.001     -0.975      0.330      -0.002       0.001
# Mkt-RF        -0.0981      0.031     -3.196      0.001      -0.158      -0.038
# SMB            0.0936      0.057      1.632      0.103      -0.019       0.206
# HML           -0.0703      0.054     -1.295      0.195      -0.177       0.036
# RMW           -0.0543      0.076     -0.717      0.473      -0.203       0.094
# CMA           -0.0634      0.097     -0.652      0.514      -0.254       0.127
# MOM            0.3483      0.127      2.744      0.006       0.099       0.597
# ==============================================================================
# Omnibus:                      775.589   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10589.868
# Skew:                           0.251   Prob(JB):                         0.00
# Kurtosis:                      10.042   Cond. No.                         371.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     3.574
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):            0.00155
# Time:                        20:24:33   Log-Likelihood:                 11758.
# No. Observations:                5392   AIC:                        -2.350e+04
# Df Residuals:                    5385   BIC:                        -2.346e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001      0.001     -0.191      0.849      -0.001       0.001
# Mkt-RF         0.0063      0.033      0.189      0.850      -0.059       0.072
# SMB            0.1287      0.062      2.076      0.038       0.007       0.250
# HML           -0.1263      0.059     -2.148      0.032      -0.242      -0.011
# RMW            0.1170      0.082      1.425      0.154      -0.044       0.278
# CMA           -0.1751      0.105     -1.673      0.094      -0.380       0.030
# MOM            0.3335      0.139      2.407      0.016       0.062       0.605
# ==============================================================================
# Omnibus:                     2692.984   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           144670.865
# Skew:                           1.621   Prob(JB):                         0.00
# Kurtosis:                      28.168   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  1878  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  4892
#
# There are  2204  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  5136
# Number of buy periods 5099
# Check number of buy periods 5099
# Number of sell periods 5392
# Check number of sell periods 5392
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        -2.17  8.05
# Ann. Tracking Error                      28.93 32.79
# Ann. Information Ratio (without T-costs) -0.08  0.25
# Skewness of Alpha                        -0.14  1.84
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       19.48 30.48
# Ann. Volatility                          38.91 43.48
# Ann. Sharpe Ratio (without T-costs)       0.50  0.70
# Skewness of Return                        0.26  1.63
# Average Turnover                          0.18  0.18
# T-costs (on 1 unit of capital)            2.73 10.20

# %%
# 20 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller20)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     3.393
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):            0.00242
# Time:                        20:24:49   Log-Likelihood:                 12850.
# No. Observations:                5478   AIC:                        -2.569e+04
# Df Residuals:                    5471   BIC:                        -2.564e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.480      0.632      -0.001       0.001
# Mkt-RF        -0.0770      0.028     -2.768      0.006      -0.132      -0.022
# SMB            0.1131      0.052      2.173      0.030       0.011       0.215
# HML           -0.0800      0.049     -1.620      0.105      -0.177       0.017
# RMW            0.0329      0.069      0.479      0.632      -0.102       0.168
# CMA           -0.0470      0.089     -0.529      0.597      -0.221       0.127
# MOM            0.2153      0.116      1.851      0.064      -0.013       0.443
# ==============================================================================
# Omnibus:                      613.967   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5861.478
# Skew:                           0.016   Prob(JB):                         0.00
# Kurtosis:                       8.067   Cond. No.                         371.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.710
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0125
# Time:                        20:24:49   Log-Likelihood:                 13100.
# No. Observations:                5771   AIC:                        -2.619e+04
# Df Residuals:                    5764   BIC:                        -2.614e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.001      0.749      0.454      -0.001       0.002
# Mkt-RF        -0.0191      0.030     -0.640      0.522      -0.078       0.039
# SMB            0.1257      0.055      2.281      0.023       0.018       0.234
# HML           -0.1014      0.053     -1.927      0.054      -0.205       0.002
# RMW            0.1004      0.073      1.371      0.170      -0.043       0.244
# CMA           -0.1644      0.093     -1.762      0.078      -0.347       0.019
# MOM            0.1025      0.122      0.838      0.402      -0.137       0.342
# ==============================================================================
# Omnibus:                     1396.369   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24350.651
# Skew:                           0.696   Prob(JB):                         0.00
# Kurtosis:                      12.966   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  1881  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  5319
#
# There are  2213  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  5593
# Number of buy periods 5478
# Check number of buy periods 5478
# Number of sell periods 5771
# Check number of sell periods 5771
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        -5.41  0.09
# Ann. Tracking Error                      26.23 28.88
# Ann. Information Ratio (without T-costs) -0.21  0.00
# Skewness of Alpha                        -0.16  0.81
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       15.46 22.11
# Ann. Volatility                          36.86 39.74
# Ann. Sharpe Ratio (without T-costs)       0.42  0.56
# Skewness of Return                        0.03  0.70
# Average Turnover                          0.15  0.16
# T-costs (on 1 unit of capital)            1.31  3.96
