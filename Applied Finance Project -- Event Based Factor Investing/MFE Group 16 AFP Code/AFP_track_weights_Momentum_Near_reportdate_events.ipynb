# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime

import ConstructPortfolio as cp #this will allow us to modularize the code!
#using "ConstructPortfolio.py" that is stored in the same directory! 
#(not using "ConstructPortfolio.ipynb")
# Out:
# /Users/bardiafarajnejad/Desktop/1st Half MFE/AFP/Final Delivery/MFE Group 16 AFP Code

# %% [markdown]
# # Trading on earnings suprises (when using midpoint) is not super informative... buy days do slighly better than sell days
#
# # Both buy and sell have high SR of 0.8-0.9 (on 20%+ returns) but low IR of 0.2 (on 2% alpha)

# %%
#### Please run the line below once in order to get "data_with_rets.pkl" from "afp_data_sample_1995_onward_v2.csv"
#cp.get_data(flag=True)

data = pd.read_pickle('data_with_rets.pkl')
data['reportdate']
# Out:
# 0          19941017.0
# 1          19941017.0
# 2          19941017.0
# 3          19941017.0
# 4          19941017.0
#               ...
# 2912427    20210428.0
# 2912428           NaN
# 2912429           NaN
# 2912430           NaN
# 2912431           NaN
# Name: reportdate, Length: 2912432, dtype: float64

# %%
data['report_date'] = pd.to_datetime(data['reportdate'], format='%Y%m%d', errors='ignore')
data['date']
# Out:
# 0         1995-01-03
# 1         1995-01-04
# 2         1995-01-05
# 3         1995-01-06
# 4         1995-01-09
#              ...
# 2912427   2021-08-05
# 2912428   2021-08-06
# 2912429   2021-08-09
# 2912430   2021-09-01
# 2912431   2021-09-02
# Name: date, Length: 2912432, dtype: datetime64[ns]

# %% [markdown]
# ### "report_date Momentum": there will potentially be information in past returns 10 days prior to 'report_date'
#
# ### Now, let's trade on report_date Momentum!
# ### the times when 'ret10d' > 0 or < 0 on report_date
# ###### Buy when 'ret10d' > 0, so when df['ret10d'] > 0 on report_date
# ###### Sell when 'ret10d' < 0, so when df['ret10d'] < 0 on report_date
# ### with 1 day, 1 week, 2 weeks, 3 weeks, and 4 weeks holding period
# ### (AHEAD, not backward... so our ret, ret5d, 10d, 15d, and 20d needs to be forward)
# ### Thus, we will use ret5d_'lag' !!
#
# # Set buy_tomorrow>0 when df['ret10d'] > 0 AND we are on report_date
# # Set Sell_tomorrow>0 when df['ret10d'] < 0 AND we are on report_date

# %%
data = data.sort_values(['osid', 'tradedate']).reset_index(drop=True).copy()

data = data[data['ret10d'].notna()].reset_index(drop=True).copy()
data = data[data['report_date'].notna()].reset_index(drop=True).copy()

data['buy_tomorrow1'] = np.where(data['ret10d'] > 0.025, 1, 0)
data['sell_tomorrow1'] = np.where(data['ret10d'] < -0.025, 1, 0)

data['buy_tomorrow2'] = np.where( (data['date']-data['report_date']).dt.days == 1, 1, 0)
data['sell_tomorrow2'] = np.where( (data['date']-data['report_date']).dt.days == 1 , 1, 0)

data['buy_tomorrow'] = data['buy_tomorrow1'] + data['buy_tomorrow2']
data['sell_tomorrow'] = data['sell_tomorrow1'] + data['sell_tomorrow2']

data['buy_tomorrow'] = np.where(data['buy_tomorrow']==2, 1, 0)
data['sell_tomorrow'] = np.where(data['sell_tomorrow']==2, 1, 0)


print('Total number of Buys: ',np.count_nonzero(data['buy_tomorrow']))
print('Total number of Sells: ',np.count_nonzero(data['sell_tomorrow']))

print('Unique buy_tomorrow values: ',np.unique(data['buy_tomorrow'])) #there are only 0 or 1 values in 'buy_tomorrow'
print('Unique sell_tomorrow values: ',np.unique(data['sell_tomorrow'])) #there are only 0 or 1 values in 'sell_tomorrow'
# Out:
# Total number of Buys:  19491
# Total number of Sells:  13485
# Unique buy_tomorrow values:  [0 1]
# Unique sell_tomorrow values:  [0 1]

# %%
data = cp.trade_on_valid_lags_only(data)
# Out:
# There are  1  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  19490
# Total number of Sells:  13485

# %% [markdown]
# # Now we can trade!
# ### Holding period of 1 week, 2 weeks, 3 weeks, and 4 weeks with equal weighted portfolios!
#
# # First, create daily equal weighted portfolio weights and returns (NOT AT THE WEEKLY frequency because that will mess up the implementation of the portfolio!). Problem is:
#
# ##### Think (part 1): 1st signal on Monday- want to buy on Tuesday and hold for 1 week in an equal weighted portfolio
# ##### Think (part 2): 2nd signal on Thursday- want to buy on Friday and hold for 1 week in an equal weighted portfolio
# ##### Think (part 3): Will have overlapping portfolio between 1st and 2nd signal on Friday and on Monday
#
# ## Then, for 1 week, 2 week, 3 week, and 4 week holding periods, we must do the following:
# ##### extend "buy_tomorrow" and "sell_tomorrow" forward for 4 more trading days

# %%
data_smaller,data_smaller5,data_smaller10,data_smaller15,data_smaller20 = cp.pull_signal_forward(data)

data_smaller20 = cp.trade_on_valid_lags_only(data_smaller20)
data_smaller15 = cp.trade_on_valid_lags_only(data_smaller15)
data_smaller10 = cp.trade_on_valid_lags_only(data_smaller10)
data_smaller5 = cp.trade_on_valid_lags_only(data_smaller5)
data_smaller = cp.trade_on_valid_lags_only(data_smaller)
# Out:
# There are  11  problems for buying
#
# There are  12  problems for selling
# Total number of Buys:  387551
# Total number of Sells:  268158
#
# There are  9  problems for buying
#
# There are  10  problems for selling
# Total number of Buys:  291008
# Total number of Sells:  201341
#
# There are  7  problems for buying
#
# There are  7  problems for selling
# Total number of Buys:  194209
# Total number of Sells:  134365
#
# There are  3  problems for buying
#
# There are  2  problems for selling
# Total number of Buys:  97203
# Total number of Sells:  67258
#
# There are  1  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  19466
# Total number of Sells:  13471

# %% [markdown]
# # First, do 1 day holding period: data_smaller
# # Next, do 5 day holding period: data_smaller5
# # Next, do 10 day holding period: data_smaller10
# # Next, do 15 day holding period: data_smaller15
# # Next, do 20 day holding period: data_smaller20

# %%
# 1 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  2  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     3.422
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):            0.00227
# Time:                        18:52:01   Log-Likelihood:                 7861.2
# No. Observations:                3494   AIC:                        -1.571e+04
# Df Residuals:                    3487   BIC:                        -1.567e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.001      1.334      0.182      -0.000       0.002
# Mkt-RF         0.1442      0.045      3.238      0.001       0.057       0.231
# SMB            0.1079      0.077      1.410      0.159      -0.042       0.258
# HML            0.0119      0.079      0.150      0.881      -0.143       0.167
# RMW            0.0062      0.099      0.063      0.950      -0.189       0.201
# CMA           -0.1584      0.128     -1.239      0.215      -0.409       0.092
# MOM           -0.1153      0.164     -0.704      0.482      -0.436       0.206
# ==============================================================================
# Omnibus:                     1633.020   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            93268.255
# Skew:                           1.428   Prob(JB):                         0.00
# Kurtosis:                      28.150   Cond. No.                         380.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.916
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           0.000667
# Time:                        18:52:01   Log-Likelihood:                 6313.5
# No. Observations:                3048   AIC:                        -1.261e+04
# Df Residuals:                    3041   BIC:                        -1.257e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.001     -1.340      0.180      -0.003       0.001
# Mkt-RF         0.0437      0.050      0.872      0.384      -0.055       0.142
# SMB            0.1421      0.091      1.558      0.119      -0.037       0.321
# HML           -0.2982      0.094     -3.161      0.002      -0.483      -0.113
# RMW            0.0432      0.122      0.354      0.723      -0.196       0.283
# CMA           -0.1623      0.156     -1.043      0.297      -0.467       0.143
# MOM            0.1929      0.208      0.925      0.355      -0.216       0.602
# ==============================================================================
# Omnibus:                      545.475   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7761.551
# Skew:                           0.411   Prob(JB):                         0.00
# Kurtosis:                      10.774   Cond. No.                         377.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  18013  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  1
#
# There are  12103  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  1
# Number of buy periods 3494
# Check number of buy periods 3494
# Number of sell periods 3048
# Check number of sell periods 3048
# Summary Statistics:
#
#                                            Buy   Sell
#
# Ann. Mean Alpha (without T-costs)        -7.00 -41.79
# Ann. Tracking Error                      34.34  42.25
# Ann. Information Ratio (without T-costs) -0.20  -0.99
# Skewness of Alpha                         0.03  -0.20
# --------------------------                  --     --
# Ann. Mean Return (without T-costs)       20.34 -13.42
# Ann. Volatility                          40.62  48.60
# Ann. Sharpe Ratio (without T-costs)       0.50  -0.28
# Skewness of Return                        1.45   0.41
# Average Turnover                          1.00   1.00
# T-costs (on 1 unit of capital)            5.07   0.59

# %%
# 5 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller5)
# Out:
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  3  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     4.324
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           0.000233
# Time:                        18:52:48   Log-Likelihood:                 15023.
# No. Observations:                5932   AIC:                        -3.003e+04
# Df Residuals:                    5925   BIC:                        -2.999e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.000     -0.474      0.635      -0.001       0.001
# Mkt-RF         0.0088      0.025      0.357      0.721      -0.039       0.057
# SMB            0.0576      0.044      1.323      0.186      -0.028       0.143
# HML            0.0255      0.044      0.585      0.558      -0.060       0.111
# RMW            0.0694      0.057      1.210      0.226      -0.043       0.182
# CMA           -0.2730      0.074     -3.706      0.000      -0.417      -0.129
# MOM            0.2542      0.094      2.715      0.007       0.071       0.438
# ==============================================================================
# Omnibus:                     1262.696   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21253.189
# Skew:                           0.558   Prob(JB):                         0.00
# Kurtosis:                      12.206   Cond. No.                         375.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     6.426
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           9.22e-07
# Time:                        18:52:48   Log-Likelihood:                 13126.
# No. Observations:                5596   AIC:                        -2.624e+04
# Df Residuals:                    5589   BIC:                        -2.619e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.883e-07      0.001     -0.001      0.999      -0.001       0.001
# Mkt-RF        -0.0246      0.028     -0.878      0.380      -0.080       0.030
# SMB            0.1468      0.052      2.818      0.005       0.045       0.249
# HML           -0.1104      0.052     -2.122      0.034      -0.212      -0.008
# RMW           -0.0127      0.070     -0.182      0.856      -0.150       0.124
# CMA           -0.2718      0.089     -3.051      0.002      -0.446      -0.097
# MOM            0.2025      0.115      1.753      0.080      -0.024       0.429
# ==============================================================================
# Omnibus:                     1770.827   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29510.866
# Skew:                           1.068   Prob(JB):                         0.00
# Kurtosis:                      14.046   Cond. No.                         373.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  18010  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  5581
#
# There are  12107  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  5157
# Number of buy periods 5932
# Check number of buy periods 5932
# Number of sell periods 5596
# Check number of sell periods 5596
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         0.00 -2.88
# Ann. Tracking Error                      23.00 28.48
# Ann. Information Ratio (without T-costs)  0.00 -0.10
# Skewness of Alpha                        -0.05  1.02
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       20.66 20.36
# Ann. Volatility                          30.59 36.93
# Ann. Sharpe Ratio (without T-costs)       0.68  0.55
# Skewness of Return                        0.55  1.05
# Average Turnover                          0.37  0.37
# T-costs (on 1 unit of capital)            6.41  6.29

# %%
# 10 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller10)
# Out:
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     5.366
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           1.55e-05
# Time:                        18:53:44   Log-Likelihood:                 16889.
# No. Observations:                6424   AIC:                        -3.376e+04
# Df Residuals:                    6417   BIC:                        -3.372e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8.227e-05      0.000     -0.222      0.824      -0.001       0.001
# Mkt-RF        -0.0154      0.020     -0.762      0.446      -0.055       0.024
# SMB            0.0240      0.037      0.641      0.522      -0.049       0.097
# HML            0.0518      0.036      1.425      0.154      -0.019       0.123
# RMW           -0.0406      0.050     -0.816      0.415      -0.138       0.057
# CMA           -0.2539      0.063     -4.043      0.000      -0.377      -0.131
# MOM            0.2736      0.081      3.366      0.001       0.114       0.433
# ==============================================================================
# Omnibus:                      993.804   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13355.986
# Skew:                           0.287   Prob(JB):                         0.00
# Kurtosis:                      10.040   Cond. No.                         373.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     6.609
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           5.60e-07
# Time:                        18:53:44   Log-Likelihood:                 15592.
# No. Observations:                6278   AIC:                        -3.117e+04
# Df Residuals:                    6271   BIC:                        -3.112e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.000     -0.554      0.580      -0.001       0.001
# Mkt-RF        -0.0356      0.023     -1.520      0.129      -0.082       0.010
# SMB            0.1117      0.043      2.588      0.010       0.027       0.196
# HML           -0.0510      0.043     -1.193      0.233      -0.135       0.033
# RMW           -0.0584      0.058     -1.008      0.314      -0.172       0.055
# CMA           -0.2475      0.073     -3.386      0.001      -0.391      -0.104
# MOM            0.2364      0.095      2.486      0.013       0.050       0.423
# ==============================================================================
# Omnibus:                     1125.633   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13790.166
# Skew:                           0.488   Prob(JB):                         0.00
# Kurtosis:                      10.195   Cond. No.                         373.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  18016  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6262
#
# There are  12114  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6053
# Number of buy periods 6424
# Check number of buy periods 6424
# Number of sell periods 6278
# Check number of sell periods 6278
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         4.10 -6.73
# Ann. Tracking Error                      18.02 22.06
# Ann. Information Ratio (without T-costs)  0.23 -0.30
# Skewness of Alpha                         0.01  0.37
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       24.77 17.05
# Ann. Volatility                          27.78 32.15
# Ann. Sharpe Ratio (without T-costs)       0.89  0.53
# Skewness of Return                        0.28  0.47
# Average Turnover                          0.25  0.26
# T-costs (on 1 unit of capital)           18.03  5.00

# %%
# 15 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller15)
# Out:
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     5.579
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           8.79e-06
# Time:                        18:54:25   Log-Likelihood:                 17538.
# No. Observations:                6593   AIC:                        -3.506e+04
# Df Residuals:                    6586   BIC:                        -3.502e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.000      0.293      0.770      -0.001       0.001
# Mkt-RF        -0.0293      0.019     -1.516      0.130      -0.067       0.009
# SMB            0.0390      0.035      1.100      0.272      -0.031       0.108
# HML            0.0328      0.034      0.953      0.341      -0.035       0.100
# RMW           -0.0669      0.047     -1.410      0.159      -0.160       0.026
# CMA           -0.2252      0.060     -3.750      0.000      -0.343      -0.107
# MOM            0.2633      0.078      3.387      0.001       0.111       0.416
# ==============================================================================
# Omnibus:                     1210.353   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28417.850
# Skew:                           0.201   Prob(JB):                         0.00
# Kurtosis:                      13.163   Cond. No.                         373.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     7.140
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           1.33e-07
# Time:                        18:54:25   Log-Likelihood:                 16731.
# No. Observations:                6535   AIC:                        -3.345e+04
# Df Residuals:                    6528   BIC:                        -3.340e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001      0.000     -0.292      0.770      -0.001       0.001
# Mkt-RF        -0.0357      0.021     -1.667      0.096      -0.078       0.006
# SMB            0.1150      0.039      2.921      0.004       0.038       0.192
# HML           -0.0526      0.039     -1.357      0.175      -0.129       0.023
# RMW           -0.0616      0.053     -1.170      0.242      -0.165       0.042
# CMA           -0.2263      0.067     -3.386      0.001      -0.357      -0.095
# MOM            0.2000      0.086      2.319      0.020       0.031       0.369
# ==============================================================================
# Omnibus:                      921.256   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10050.386
# Skew:                           0.291   Prob(JB):                         0.00
# Kurtosis:                       9.047   Cond. No.                         373.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  18022  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6535
#
# There are  12123  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6437
# Number of buy periods 6593
# Check number of buy periods 6593
# Number of sell periods 6535
# Check number of sell periods 6535
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         6.90 -5.60
# Ann. Tracking Error                      16.36 19.06
# Ann. Information Ratio (without T-costs)  0.42 -0.29
# Skewness of Alpha                         0.53  0.43
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       28.34 16.89
# Ann. Volatility                          26.93 29.78
# Ann. Sharpe Ratio (without T-costs)       1.05  0.57
# Skewness of Return                        0.22  0.26
# Average Turnover                          0.19  0.20
# T-costs (on 1 unit of capital)           52.15  5.41

# %%
# 20 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller20)
# Out:
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  2  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     7.813
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           2.12e-08
# Time:                        18:55:00   Log-Likelihood:                 17884.
# No. Observations:                6642   AIC:                        -3.575e+04
# Df Residuals:                    6635   BIC:                        -3.571e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.207e-05      0.000      0.152      0.879      -0.001       0.001
# Mkt-RF        -0.0553      0.019     -2.963      0.003      -0.092      -0.019
# SMB            0.0343      0.034      1.002      0.316      -0.033       0.101
# HML           -0.0315      0.033     -0.945      0.345      -0.097       0.034
# RMW           -0.0777      0.046     -1.695      0.090      -0.168       0.012
# CMA           -0.2101      0.058     -3.622      0.000      -0.324      -0.096
# MOM            0.2694      0.075      3.598      0.000       0.123       0.416
# ==============================================================================
# Omnibus:                      850.390   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9195.611
# Skew:                          -0.177   Prob(JB):                         0.00
# Kurtosis:                       8.753   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     7.110
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           1.44e-07
# Time:                        18:55:00   Log-Likelihood:                 16978.
# No. Observations:                6608   AIC:                        -3.394e+04
# Df Residuals:                    6601   BIC:                        -3.389e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.000      0.304      0.761      -0.001       0.001
# Mkt-RF        -0.0401      0.021     -1.896      0.058      -0.081       0.001
# SMB            0.1298      0.039      3.349      0.001       0.054       0.206
# HML           -0.0600      0.038     -1.568      0.117      -0.135       0.015
# RMW           -0.0507      0.052     -0.976      0.329      -0.153       0.051
# CMA           -0.2038      0.066     -3.088      0.002      -0.333      -0.074
# MOM            0.1954      0.085      2.302      0.021       0.029       0.362
# ==============================================================================
# Omnibus:                     2072.167   Durbin-Watson:                   1.908
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            52386.637
# Skew:                           0.934   Prob(JB):                         0.00
# Kurtosis:                      16.667   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  18021  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6619
#
# There are  12149  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6572
# Number of buy periods 6642
# Check number of buy periods 6642
# Number of sell periods 6608
# Check number of sell periods 6608
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         6.11 -1.02
# Ann. Tracking Error                      14.41 18.24
# Ann. Information Ratio (without T-costs)  0.42 -0.06
# Skewness of Alpha                         0.17  2.64
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       27.29 22.44
# Ann. Volatility                          26.10 29.51
# Ann. Sharpe Ratio (without T-costs)       1.05  0.76
# Skewness of Return                       -0.19  0.90
# Average Turnover                          0.16  0.16
# T-costs (on 1 unit of capital)           51.87  6.58
