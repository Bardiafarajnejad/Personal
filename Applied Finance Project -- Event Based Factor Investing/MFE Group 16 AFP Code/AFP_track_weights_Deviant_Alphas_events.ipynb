# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime

import ConstructPortfolio as cp #this will allow us to modularize the code!
#using "ConstructPortfolio.py" that is stored in the same directory! 
#(not using "ConstructPortfolio.ipynb")
# Out:
# /Users/bardiafarajnejad/Desktop/1st Half MFE/AFP/Final Delivery/MFE Group 16 AFP Code

# %%
#### Please run the line below once in order to get "data_with_rets.pkl" from "afp_data_sample_1995_onward_v2.csv"
#cp.get_data(flag=True)

data = pd.read_pickle('data_with_rets.pkl')
data
# Out:
#          tradedate   osid symbol                    coname  sector_group  \
# 0         19950103  10032    ACK  Armstrong Holdings Inc             7.0
# 1         19950104  10032    ACK  Armstrong Holdings Inc             7.0
# 2         19950105  10032    ACK  Armstrong Holdings Inc             7.0
# 3         19950106  10032    ACK  Armstrong Holdings Inc             7.0
# 4         19950109  10032    ACK  Armstrong Holdings Inc             7.0
# ...            ...    ...    ...                       ...           ...
# 2912427   20210805  78696   COOK               Traeger Inc           7.0
# 2912428   20210806  78722   WEBR            Weber Inc Cl A           NaN
# 2912429   20210809  78722   WEBR            Weber Inc Cl A           7.0
# 2912430   20210901  78803   FCUV       Focus Universal Inc           NaN
# 2912431   20210902  78803   FCUV       Focus Universal Inc           4.0
#
#            max_dt  previoustradedate  tickssinceipo     alpha  stdev_alpha  \
# 0        19970827         19941230.0           8056  0.010006     0.004670
# 1        19970827         19950103.0           8057 -0.003112     0.004656
# 2        19970827         19950104.0           8058  0.019820     0.005805
# 3        19970827         19950105.0           8059  0.045571     0.009709
# 4        19970827         19950106.0           8060  0.032296     0.010892
# ...           ...                ...            ...       ...          ...
# 2912427  20210805         20210804.0              6  0.047968     0.026349
# 2912428  20210809         20210805.0              2  0.000000     0.000000
# 2912429  20210809         20210806.0              3  0.080042     0.025773
# 2912430  20210902         20210831.0              2  0.000000     0.000000
# 2912431  20210902         20210901.0              3 -0.072293     0.019244
#
#          ...  ret1d_lag  alpha1d_lag  ret5d_lag  alpha5d_lag  ret10d_lag  \
# 0        ...    0.00000    -0.003112   0.176850     0.166677    0.131841
# 1        ...    0.01929     0.019820   0.131835     0.124719    0.125412
# 2        ...    0.04732     0.045571   0.119876     0.112258    0.094651
# 3        ...    0.03313     0.032296   0.069278     0.054748    0.063264
# 4        ...    0.06706     0.063220   0.058317     0.037605    0.020420
# ...      ...        ...          ...        ...          ...         ...
# 2912427  ...        NaN          NaN        NaN          NaN         NaN
# 2912428  ...    0.08190     0.080042        NaN          NaN         NaN
# 2912429  ...        NaN          NaN        NaN          NaN         NaN
# 2912430  ...   -0.07106    -0.072293        NaN          NaN         NaN
# 2912431  ...        NaN          NaN        NaN          NaN         NaN
#
#          alpha10d_lag  ret15d_lag  alpha15d_lag  ret20d_lag  alpha20d_lag
# 0            0.102035    0.144700      0.123317    0.138261      0.106187
# 1            0.099894    0.173638      0.151438    0.144692      0.115932
# 2            0.075155    0.170357      0.145504    0.135652      0.101416
# 3            0.050293    0.096391      0.070299    0.090370      0.047479
# 4            0.006697    0.046651      0.026290    0.072892      0.026535
# ...               ...         ...           ...         ...           ...
# 2912427           NaN         NaN           NaN         NaN           NaN
# 2912428           NaN         NaN           NaN         NaN           NaN
# 2912429           NaN         NaN           NaN         NaN           NaN
# 2912430           NaN         NaN           NaN         NaN           NaN
# 2912431           NaN         NaN           NaN         NaN           NaN
#
# [2912432 rows x 175 columns]

# %% [markdown]
# ### Now, let's trade on the times when there is an Alpha in excess of 2 Stdev from 0

# %%
#define event using indicator for buy and sell:
data = data.sort_values(['osid', 'tradedate']).reset_index(drop=True).copy()

data['buy_tomorrow'] = ((data['alpha'] / data['stdev_alpha']) < -2)
data['sell_tomorrow'] = ((data['alpha'] / data['stdev_alpha']) > 2)


print('Total number of Buys: ',np.count_nonzero(data['buy_tomorrow']))
print('Total number of Sells: ',np.count_nonzero(data['sell_tomorrow']))

print('Unique buy_tomorrow values: ',np.unique(data['buy_tomorrow'])) #there is at least one '2' that occurs, which means that one stock was included in 2 indices in one day!
print('Unique sell_tomorrow values: ',np.unique(data['sell_tomorrow'])) #there is at least one '2' that occurs, which means that one stock was removed from 2 indices in one day!
# Out:
# Total number of Buys:  120558
# Total number of Sells:  137418
# Unique buy_tomorrow values:  [False  True]
# Unique sell_tomorrow values:  [False  True]

# %%
data = cp.trade_on_valid_lags_only(data)
# Out:
# There are  2  problems for buying
#
# There are  15  problems for selling
# Total number of Buys:  120556
# Total number of Sells:  137403

# %% [markdown]
# # Now we can trade!
# ### Holding period of 1 week, 2 weeks, 3 weeks, and 4 weeks with equal weighted portfolios!
#
# # First, create daily equal weighted portfolio weights and returns (NOT AT THE WEEKLY frequency because that will mess up the implementation of the portfolio!). Problem is:
#
# ##### Think (part 1): 1st signal on Monday- want to buy on Tuesday and hold for 1 week in an equal weighted portfolio
# ##### Think (part 2): 2nd signal on Thursday- want to buy on Friday and hold for 1 week in an equal weighted portfolio
# ##### Think (part 3): Will have overlapping portfolio between 1st and 2nd signal on Friday and on Monday
#
# ## Then, for 1 week, 2 week, 3 week, and 4 week holding periods, we must do the following:
# ##### extend "buy_tomorrow" and "sell_tomorrow" forward for 4 more trading days

# %%
data_smaller,data_smaller5,data_smaller10,data_smaller15,data_smaller20 = cp.pull_signal_forward(data)

data_smaller20 = cp.trade_on_valid_lags_only(data_smaller20)
data_smaller15 = cp.trade_on_valid_lags_only(data_smaller15)
data_smaller10 = cp.trade_on_valid_lags_only(data_smaller10)
data_smaller5 = cp.trade_on_valid_lags_only(data_smaller5)
data_smaller = cp.trade_on_valid_lags_only(data_smaller)
# Out:
# There are  51  problems for buying
#
# There are  76  problems for selling
# Total number of Buys:  1481079
# Total number of Sells:  1684456
#
# There are  39  problems for buying
#
# There are  62  problems for selling
# Total number of Buys:  1214568
# Total number of Sells:  1392732
#
# There are  30  problems for buying
#
# There are  45  problems for selling
# Total number of Buys:  898559
# Total number of Sells:  1035780
#
# There are  23  problems for buying
#
# There are  30  problems for selling
# Total number of Buys:  512289
# Total number of Sells:  589635
#
# There are  3  problems for buying
#
# There are  9  problems for selling
# Total number of Buys:  120396
# Total number of Sells:  137208

# %% [markdown]
# # First, do 1 day holding period: data_smaller
# # Next, do 5 day holding period: data_smaller5
# # Next, do 10 day holding period: data_smaller10
# # Next, do 15 day holding period: data_smaller15
# # Next, do 20 day holding period: data_smaller20

# %%
# 1 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller)
# Out:
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.156
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):            0.00431
# Time:                        14:17:32   Log-Likelihood:                 15311.
# No. Observations:                6484   AIC:                        -3.061e+04
# Df Residuals:                    6477   BIC:                        -3.056e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.000      3.595      0.000       0.001       0.003
# Mkt-RF        -0.0689      0.026     -2.626      0.009      -0.120      -0.017
# SMB            0.1415      0.048      2.945      0.003       0.047       0.236
# HML           -0.0248      0.047     -0.532      0.595      -0.116       0.067
# RMW            0.0139      0.064      0.216      0.829      -0.112       0.140
# CMA           -0.1396      0.081     -1.721      0.085      -0.299       0.019
# MOM            0.0928      0.105      0.880      0.379      -0.114       0.300
# ==============================================================================
# Omnibus:                      948.748   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12032.933
# Skew:                           0.250   Prob(JB):                         0.00
# Kurtosis:                       9.655   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     3.954
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):           0.000596
# Time:                        14:17:32   Log-Likelihood:                 16262.
# No. Observations:                6619   AIC:                        -3.251e+04
# Df Residuals:                    6612   BIC:                        -3.246e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.000      2.158      0.031     8.6e-05       0.002
# Mkt-RF        -0.0273      0.024     -1.153      0.249      -0.074       0.019
# SMB            0.1521      0.043      3.508      0.000       0.067       0.237
# HML           -0.0918      0.042     -2.187      0.029      -0.174      -0.010
# RMW            0.0174      0.058      0.299      0.765      -0.097       0.132
# CMA           -0.0810      0.074     -1.101      0.271      -0.225       0.063
# MOM            0.1471      0.095      1.552      0.121      -0.039       0.333
# ==============================================================================
# Omnibus:                     2213.694   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            82399.320
# Skew:                           0.920   Prob(JB):                         0.00
# Kurtosis:                      20.187   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  92376  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  4317
#
# There are  107499  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  4808
# Number of buy periods 6484
# Check number of buy periods 6484
# Number of sell periods 6619
# Check number of sell periods 6619
# Summary Statistics:
#
#                                               Buy   Sell
#
# Ann. Mean Alpha (without T-costs)           23.15   9.73
# Ann. Tracking Error                         27.06  23.92
# Ann. Information Ratio (without T-costs)     0.86   0.41
# Skewness of Alpha                           -0.17   0.47
# --------------------------                     --     --
# Ann. Mean Return (without T-costs)          53.61  39.50
# Ann. Volatility                             36.28  32.99
# Ann. Sharpe Ratio (without T-costs)          1.48   1.20
# Skewness of Return                           0.25   0.91
# Average Turnover                             0.94   0.93
# T-costs (on 1 unit of capital)           3,842.44 203.06

# %%
# 5 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller5)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  2  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     5.427
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):           1.31e-05
# Time:                        14:17:49   Log-Likelihood:                 17625.
# No. Observations:                6712   AIC:                        -3.524e+04
# Df Residuals:                    6705   BIC:                        -3.519e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.000      2.809      0.005       0.000       0.002
# Mkt-RF        -0.0465      0.020     -2.345      0.019      -0.085      -0.008
# SMB            0.0948      0.036      2.615      0.009       0.024       0.166
# HML           -0.0499      0.035     -1.421      0.155      -0.119       0.019
# RMW           -0.0149      0.049     -0.306      0.760      -0.111       0.081
# CMA           -0.1942      0.062     -3.147      0.002      -0.315      -0.073
# MOM            0.1328      0.079      1.670      0.095      -0.023       0.289
# ==============================================================================
# Omnibus:                     1038.501   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16335.764
# Skew:                           0.186   Prob(JB):                         0.00
# Kurtosis:                      10.634   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     5.540
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):           9.74e-06
# Time:                        14:17:49   Log-Likelihood:                 18137.
# No. Observations:                6715   AIC:                        -3.626e+04
# Df Residuals:                    6708   BIC:                        -3.621e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.000      2.118      0.034    5.35e-05       0.001
# Mkt-RF        -0.0435      0.018     -2.366      0.018      -0.080      -0.007
# SMB            0.0849      0.034      2.524      0.012       0.019       0.151
# HML           -0.0633      0.033     -1.943      0.052      -0.127       0.001
# RMW           -0.0280      0.045     -0.618      0.537      -0.117       0.061
# CMA           -0.1607      0.057     -2.807      0.005      -0.273      -0.049
# MOM            0.0921      0.074      1.250      0.211      -0.052       0.237
# ==============================================================================
# Omnibus:                      797.639   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8414.640
# Skew:                           0.031   Prob(JB):                         0.00
# Kurtosis:                       8.484   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  75493  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6705
#
# There are  87592  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6711
# Number of buy periods 6712
# Check number of buy periods 6712
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                             Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         12.78  2.85
# Ann. Tracking Error                       15.16 13.65
# Ann. Information Ratio (without T-costs)   0.84  0.21
# Skewness of Alpha                         -0.00 -0.05
# --------------------------                   --    --
# Ann. Mean Return (without T-costs)        39.52 27.98
# Ann. Volatility                           27.87 25.86
# Ann. Sharpe Ratio (without T-costs)        1.42  1.08
# Skewness of Return                         0.15  0.01
# Average Turnover                           0.30  0.28
# T-costs (on 1 unit of capital)           786.22 38.09

# %%
# 10 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller10)
# Out:
# There are  2  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  3  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.492
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):              0.176
# Time:                        14:18:13   Log-Likelihood:                 6503.9
# No. Observations:                6715   AIC:                        -1.299e+04
# Df Residuals:                    6708   BIC:                        -1.295e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001      0.002     -0.078      0.938      -0.004       0.004
# Mkt-RF         0.1287      0.104      1.237      0.216      -0.075       0.333
# SMB            0.3999      0.190      2.103      0.036       0.027       0.773
# HML           -0.0394      0.184     -0.214      0.831      -0.401       0.322
# RMW            0.3735      0.256      1.459      0.145      -0.128       0.875
# CMA           -0.1936      0.324     -0.598      0.550      -0.828       0.441
# MOM            0.6353      0.417      1.524      0.128      -0.182       1.453
# ==============================================================================
# Omnibus:                    24662.462   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      10948352608.662
# Skew:                          77.711   Prob(JB):                         0.00
# Kurtosis:                    6256.496   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     7.760
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):           2.45e-08
# Time:                        14:18:13   Log-Likelihood:                 18265.
# No. Observations:                6715   AIC:                        -3.652e+04
# Df Residuals:                    6708   BIC:                        -3.647e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.000      1.714      0.086   -8.15e-05       0.001
# Mkt-RF        -0.0424      0.018     -2.347      0.019      -0.078      -0.007
# SMB            0.0852      0.033      2.580      0.010       0.020       0.150
# HML           -0.0702      0.032     -2.196      0.028      -0.133      -0.008
# RMW           -0.0356      0.044     -0.802      0.422      -0.123       0.051
# CMA           -0.1971      0.056     -3.509      0.000      -0.307      -0.087
# MOM            0.1439      0.072      1.989      0.047       0.002       0.286
# ==============================================================================
# Omnibus:                      785.112   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7768.495
# Skew:                          -0.106   Prob(JB):                         0.00
# Kurtosis:                       8.265   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  61999  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
#
# There are  70219  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 6715
# Check number of buy periods 6715
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                               Buy  Sell
#
# Ann. Mean Alpha (without T-costs)            7.72  4.65
# Ann. Tracking Error                         13.53 12.43
# Ann. Information Ratio (without T-costs)     0.57  0.37
# Skewness of Alpha                           -0.25 -0.35
# --------------------------                     --    --
# Ann. Mean Return (without T-costs)          60.79 28.99
# Ann. Volatility                            145.93 25.39
# Ann. Sharpe Ratio (without T-costs)          0.42  1.14
# Skewness of Return                          77.84 -0.13
# Average Turnover                             0.16  0.15
# T-costs (on 1 unit of capital)           1,449.20 59.84

# %%
# 15 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller15)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.678
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):              0.122
# Time:                        14:18:45   Log-Likelihood:                 8660.0
# No. Observations:                6715   AIC:                        -1.731e+04
# Df Residuals:                    6708   BIC:                        -1.726e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.358e-05      0.001     -0.010      0.992      -0.003       0.003
# Mkt-RF         0.0776      0.075      1.029      0.304      -0.070       0.226
# SMB            0.3118      0.138      2.260      0.024       0.041       0.582
# HML           -0.0510      0.134     -0.382      0.703      -0.313       0.211
# RMW            0.2563      0.186      1.380      0.168      -0.108       0.620
# CMA           -0.2070      0.235     -0.882      0.378      -0.667       0.253
# MOM            0.5004      0.302      1.655      0.098      -0.092       1.093
# ==============================================================================
# Omnibus:                    24303.289   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       9722903886.723
# Skew:                          74.327   Prob(JB):                         0.00
# Kurtosis:                    5896.082   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     8.291
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):           5.71e-09
# Time:                        14:18:45   Log-Likelihood:                 18279.
# No. Observations:                6715   AIC:                        -3.654e+04
# Df Residuals:                    6708   BIC:                        -3.650e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.000      1.671      0.095   -9.58e-05       0.001
# Mkt-RF        -0.0411      0.018     -2.283      0.022      -0.076      -0.006
# SMB            0.0832      0.033      2.526      0.012       0.019       0.148
# HML           -0.0774      0.032     -2.426      0.015      -0.140      -0.015
# RMW           -0.0390      0.044     -0.879      0.380      -0.126       0.048
# CMA           -0.1955      0.056     -3.486      0.000      -0.305      -0.086
# MOM            0.1601      0.072      2.218      0.027       0.019       0.302
# ==============================================================================
# Omnibus:                      808.434   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8367.537
# Skew:                          -0.112   Prob(JB):                         0.00
# Kurtosis:                       8.464   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  52379  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
#
# There are  57513  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 6715
# Check number of buy periods 6715
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                             Buy  Sell
#
# Ann. Mean Alpha (without T-costs)          5.95  6.01
# Ann. Tracking Error                       12.88 12.07
# Ann. Information Ratio (without T-costs)   0.46  0.50
# Skewness of Alpha                         -0.32 -0.31
# --------------------------                   --    --
# Ann. Mean Return (without T-costs)        50.40 30.11
# Ann. Volatility                          105.86 25.35
# Ann. Sharpe Ratio (without T-costs)        0.48  1.19
# Skewness of Return                        74.43 -0.14
# Average Turnover                           0.11  0.10
# T-costs (on 1 unit of capital)           485.71 67.71

# %%
# 20 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller20)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.019
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):             0.0597
# Time:                        14:19:18   Log-Likelihood:                 10591.
# No. Observations:                6715   AIC:                        -2.117e+04
# Df Residuals:                    6708   BIC:                        -2.112e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.177e-05      0.001      0.069      0.945      -0.002       0.002
# Mkt-RF         0.0448      0.057      0.791      0.429      -0.066       0.156
# SMB            0.2524      0.103      2.439      0.015       0.050       0.455
# HML           -0.0534      0.100     -0.532      0.595      -0.250       0.143
# RMW            0.1820      0.139      1.306      0.191      -0.091       0.455
# CMA           -0.2164      0.176     -1.228      0.219      -0.562       0.129
# MOM            0.4145      0.227      1.827      0.068      -0.030       0.859
# ==============================================================================
# Omnibus:                    23705.244   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       7962656925.490
# Skew:                          68.963   Prob(JB):                         0.00
# Kurtosis:                    5335.936   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.889
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):             0.0788
# Time:                        14:19:18   Log-Likelihood:                 10216.
# No. Observations:                6715   AIC:                        -2.042e+04
# Df Residuals:                    6708   BIC:                        -2.037e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.756e-05      0.001      0.025      0.980      -0.002       0.002
# Mkt-RF         0.0564      0.060      0.943      0.346      -0.061       0.174
# SMB            0.2498      0.109      2.283      0.022       0.035       0.464
# HML           -0.0702      0.106     -0.662      0.508      -0.278       0.138
# RMW            0.1782      0.147      1.210      0.226      -0.111       0.467
# CMA           -0.1906      0.186     -1.023      0.306      -0.556       0.175
# MOM            0.4394      0.240      1.832      0.067      -0.031       0.910
# ==============================================================================
# Omnibus:                    23926.802   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       8577715053.532
# Skew:                          70.912   Prob(JB):                         0.00
# Kurtosis:                    5538.106   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  45364  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
#
# There are  47688  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 6715
# Check number of buy periods 6715
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                             Buy   Sell
#
# Ann. Mean Alpha (without T-costs)          4.92   5.94
# Ann. Tracking Error                       12.55  11.96
# Ann. Information Ratio (without T-costs)   0.39   0.50
# Skewness of Alpha                         -0.29  -0.35
# --------------------------                   --     --
# Ann. Mean Return (without T-costs)        43.77  45.12
# Ann. Volatility                           79.41  83.97
# Ann. Sharpe Ratio (without T-costs)        0.55   0.54
# Skewness of Return                        69.03  70.99
# Average Turnover                           0.09   0.08
# T-costs (on 1 unit of capital)           220.72 246.01
