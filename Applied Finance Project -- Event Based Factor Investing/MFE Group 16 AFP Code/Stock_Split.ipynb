# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime

import ConstructPortfolio as cp #this will allow us to modularize the code!
#using "ConstructPortfolio.py" that is stored in the same directory! 
#(not using "ConstructPortfolio.ipynb")
# Out:
# /Users/bardiafarajnejad/Desktop/1st Half MFE/AFP/Final Delivery/MFE Group 16 AFP Code

# %%
#### Please run the line below once in order to get "data_with_rets.pkl" from "afp_data_sample_1995_onward_v2.csv"
#cp.get_data(flag=True)

data = pd.read_pickle('data_with_rets.pkl')
data.head()
# Out:
#    tradedate   osid symbol                    coname  sector_group    max_dt  \
# 0   19950103  10032    ACK  Armstrong Holdings Inc             7.0  19970827
# 1   19950104  10032    ACK  Armstrong Holdings Inc             7.0  19970827
# 2   19950105  10032    ACK  Armstrong Holdings Inc             7.0  19970827
# 3   19950106  10032    ACK  Armstrong Holdings Inc             7.0  19970827
# 4   19950109  10032    ACK  Armstrong Holdings Inc             7.0  19970827
#
#    previoustradedate  tickssinceipo     alpha  stdev_alpha  ...  ret1d_lag  \
# 0         19941230.0           8056  0.010006     0.004670  ...    0.00000
# 1         19950103.0           8057 -0.003112     0.004656  ...    0.01929
# 2         19950104.0           8058  0.019820     0.005805  ...    0.04732
# 3         19950105.0           8059  0.045571     0.009709  ...    0.03313
# 4         19950106.0           8060  0.032296     0.010892  ...    0.06706
#
#    alpha1d_lag  ret5d_lag  alpha5d_lag  ret10d_lag  alpha10d_lag  ret15d_lag  \
# 0    -0.003112   0.176850     0.166677    0.131841      0.102035    0.144700
# 1     0.019820   0.131835     0.124719    0.125412      0.099894    0.173638
# 2     0.045571   0.119876     0.112258    0.094651      0.075155    0.170357
# 3     0.032296   0.069278     0.054748    0.063264      0.050293    0.096391
# 4     0.063220   0.058317     0.037605    0.020420      0.006697    0.046651
#
#    alpha15d_lag  ret20d_lag  alpha20d_lag
# 0      0.123317    0.138261      0.106187
# 1      0.151438    0.144692      0.115932
# 2      0.145504    0.135652      0.101416
# 3      0.070299    0.090370      0.047479
# 4      0.026290    0.072892      0.026535
#
# [5 rows x 175 columns]

# %% [markdown]
# # Buy when there is a stock split

# %%
#define event using indicator for buy and sell:
data = data.sort_values(['osid', 'tradedate']).reset_index(drop=True).copy()

data = data.loc[data['splitfactor'].notna(),:].reset_index(drop=True).copy()

data['buy_tomorrow'] = np.where(data['splitfactor']> 1, 1, 0)
data['sell_tomorrow'] = np.where(data['splitfactor']> 1, 1, 0)


print('Total number of Buys: ',np.count_nonzero(data['buy_tomorrow']))
print('Total number of Sells: ',np.count_nonzero(data['sell_tomorrow']))

print('Unique buy_tomorrow values: ',np.unique(data['buy_tomorrow'])) #there are only 0 or 1 values in 'buy_tomorrow'
print('Unique sell_tomorrow values: ',np.unique(data['sell_tomorrow'])) #there are only 0 or 1 values in 'sell_tomorrow'
# Out:
# Total number of Buys:  955
# Total number of Sells:  955
# Unique buy_tomorrow values:  [0 1]
# Unique sell_tomorrow values:  [0 1]

# %%
data = cp.trade_on_valid_lags_only(data)
# Out:
# There are  0  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  955
# Total number of Sells:  955

# %% [markdown]
# # Now we can trade!
# ### Holding period of 1 week, 2 weeks, 3 weeks, and 4 weeks with equal weighted portfolios!

# %%
data_smaller,data_smaller5,data_smaller10,data_smaller15,data_smaller20 = cp.pull_signal_forward(data)

data_smaller20 = cp.trade_on_valid_lags_only(data_smaller20)
data_smaller15 = cp.trade_on_valid_lags_only(data_smaller15)
data_smaller10 = cp.trade_on_valid_lags_only(data_smaller10)
data_smaller5 = cp.trade_on_valid_lags_only(data_smaller5)
data_smaller = cp.trade_on_valid_lags_only(data_smaller)
# Out:
# There are  0  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  19024
# Total number of Sells:  19024
#
# There are  0  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  14280
# Total number of Sells:  14280
#
# There are  0  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  9528
# Total number of Sells:  9528
#
# There are  0  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  4769
# Total number of Sells:  4769
#
# There are  0  problems for buying
#
# There are  0  problems for selling
# Total number of Buys:  955
# Total number of Sells:  955

# %% [markdown]
# # First, do 1 day holding period: data_smaller
# # Next, do 5 day holding period: data_smaller5
# # Next, do 10 day holding period: data_smaller10
# # Next, do 15 day holding period: data_smaller15
# # Next, do 20 day holding period: data_smaller20

# %%
# 1 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.8630
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):              0.522
# Time:                        13:57:36   Log-Likelihood:                 1073.6
# No. Observations:                 740   AIC:                            -2133.
# Df Residuals:                     733   BIC:                            -2101.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.004      0.767      0.444      -0.004       0.010
# Mkt-RF        -0.0225      0.236     -0.095      0.924      -0.486       0.442
# SMB           -0.1788      0.379     -0.472      0.637      -0.923       0.565
# HML           -0.6720      0.477     -1.409      0.159      -1.608       0.264
# RMW           -0.2775      0.461     -0.602      0.547      -1.183       0.628
# CMA            0.5344      0.581      0.920      0.358      -0.606       1.674
# MOM            1.0245      0.804      1.274      0.203      -0.554       2.603
# ==============================================================================
# Omnibus:                      530.049   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19431.850
# Skew:                           2.742   Prob(JB):                         0.00
# Kurtosis:                      27.498   Cond. No.                         385.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.8630
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):              0.522
# Time:                        13:57:36   Log-Likelihood:                 1073.6
# No. Observations:                 740   AIC:                            -2133.
# Df Residuals:                     733   BIC:                            -2101.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.004      0.767      0.444      -0.004       0.010
# Mkt-RF        -0.0225      0.236     -0.095      0.924      -0.486       0.442
# SMB           -0.1788      0.379     -0.472      0.637      -0.923       0.565
# HML           -0.6720      0.477     -1.409      0.159      -1.608       0.264
# RMW           -0.2775      0.461     -0.602      0.547      -1.183       0.628
# CMA            0.5344      0.581      0.920      0.358      -0.606       1.674
# MOM            1.0245      0.804      1.274      0.203      -0.554       2.603
# ==============================================================================
# Omnibus:                      530.049   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19431.850
# Skew:                           2.742   Prob(JB):                         0.00
# Kurtosis:                      27.498   Cond. No.                         385.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  368  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  0
#
# There are  368  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  0
# Number of buy periods 740
# Check number of buy periods 740
# Number of sell periods 740
# Check number of sell periods 740
# Summary Statistics:
#
#                                             Buy   Sell
#
# Ann. Mean Alpha (without T-costs)         85.60  85.60
# Ann. Tracking Error                       78.30  78.30
# Ann. Information Ratio (without T-costs)   1.09   1.09
# Skewness of Alpha                          1.49   1.49
# --------------------------                   --     --
# Ann. Mean Return (without T-costs)       163.60 163.60
# Ann. Volatility                           90.41  90.41
# Ann. Sharpe Ratio (without T-costs)        1.81   1.81
# Skewness of Return                         2.71   2.71
# Average Turnover                           1.00   1.00
# T-costs (on 1 unit of capital)             6.53   6.53

# %%
# 5 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller5)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.174
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):              0.317
# Time:                        13:57:44   Log-Likelihood:                 3902.9
# No. Observations:                2168   AIC:                            -7792.
# Df Residuals:                    2161   BIC:                            -7752.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.001     -0.574      0.566      -0.004       0.002
# Mkt-RF         0.0610      0.096      0.635      0.526      -0.128       0.250
# SMB           -0.1718      0.156     -1.098      0.272      -0.479       0.135
# HML           -0.0147      0.184     -0.080      0.936      -0.376       0.346
# RMW           -0.1694      0.192     -0.884      0.377      -0.545       0.206
# CMA            0.0363      0.244      0.149      0.882      -0.441       0.514
# MOM            0.6279      0.327      1.922      0.055      -0.013       1.269
# ==============================================================================
# Omnibus:                      429.930   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7489.324
# Skew:                           0.433   Prob(JB):                         0.00
# Kurtosis:                      12.064   Cond. No.                         380.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.174
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):              0.317
# Time:                        13:57:44   Log-Likelihood:                 3902.9
# No. Observations:                2168   AIC:                            -7792.
# Df Residuals:                    2161   BIC:                            -7752.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.001     -0.574      0.566      -0.004       0.002
# Mkt-RF         0.0610      0.096      0.635      0.526      -0.128       0.250
# SMB           -0.1718      0.156     -1.098      0.272      -0.479       0.135
# HML           -0.0147      0.184     -0.080      0.936      -0.376       0.346
# RMW           -0.1694      0.192     -0.884      0.377      -0.545       0.206
# CMA            0.0363      0.244      0.149      0.882      -0.441       0.514
# MOM            0.6279      0.327      1.922      0.055      -0.013       1.269
# ==============================================================================
# Omnibus:                      429.930   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7489.324
# Skew:                           0.433   Prob(JB):                         0.00
# Kurtosis:                      12.064   Cond. No.                         380.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  368  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  1817
#
# There are  368  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  1817
# Number of buy periods 2168
# Check number of buy periods 2168
# Number of sell periods 2168
# Check number of sell periods 2168
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         2.24  2.24
# Ann. Tracking Error                      54.86 54.86
# Ann. Information Ratio (without T-costs)  0.04  0.04
# Skewness of Alpha                        -0.52 -0.52
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       39.28 39.28
# Ann. Volatility                          63.60 63.60
# Ann. Sharpe Ratio (without T-costs)       0.62  0.62
# Skewness of Return                        0.45  0.45
# Average Turnover                          0.32  0.32
# T-costs (on 1 unit of capital)            3.01  3.01

# %%
# 10 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller10)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.060
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):             0.0548
# Time:                        13:57:51   Log-Likelihood:                 5964.3
# No. Observations:                2975   AIC:                        -1.191e+04
# Df Residuals:                    2968   BIC:                        -1.187e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.306      0.760      -0.002       0.002
# Mkt-RF         0.0791      0.063      1.261      0.208      -0.044       0.202
# SMB            0.0226      0.106      0.213      0.831      -0.185       0.230
# HML           -0.1504      0.117     -1.286      0.198      -0.380       0.079
# RMW            0.0861      0.134      0.641      0.522      -0.177       0.350
# CMA           -0.1521      0.167     -0.911      0.362      -0.479       0.175
# MOM            0.3401      0.227      1.497      0.135      -0.105       0.786
# ==============================================================================
# Omnibus:                      547.054   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9355.633
# Skew:                           0.361   Prob(JB):                         0.00
# Kurtosis:                      11.658   Cond. No.                         380.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.060
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):             0.0548
# Time:                        13:57:51   Log-Likelihood:                 5964.3
# No. Observations:                2975   AIC:                        -1.191e+04
# Df Residuals:                    2968   BIC:                        -1.187e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.306      0.760      -0.002       0.002
# Mkt-RF         0.0791      0.063      1.261      0.208      -0.044       0.202
# SMB            0.0226      0.106      0.213      0.831      -0.185       0.230
# HML           -0.1504      0.117     -1.286      0.198      -0.380       0.079
# RMW            0.0861      0.134      0.641      0.522      -0.177       0.350
# CMA           -0.1521      0.167     -0.911      0.362      -0.479       0.175
# MOM            0.3401      0.227      1.497      0.135      -0.105       0.786
# ==============================================================================
# Omnibus:                      547.054   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9355.633
# Skew:                           0.361   Prob(JB):                         0.00
# Kurtosis:                      11.658   Cond. No.                         380.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  369  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  2762
#
# There are  369  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  2762
# Number of buy periods 2975
# Check number of buy periods 2975
# Number of sell periods 2975
# Check number of sell periods 2975
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        -1.87 -1.87
# Ann. Tracking Error                      43.80 43.80
# Ann. Information Ratio (without T-costs) -0.04 -0.04
# Skewness of Alpha                        -0.62 -0.62
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       25.15 25.15
# Ann. Volatility                          51.85 51.85
# Ann. Sharpe Ratio (without T-costs)       0.48  0.48
# Skewness of Return                        0.36  0.36
# Average Turnover                          0.19  0.19
# T-costs (on 1 unit of capital)            1.83  1.83

# %%
# 15 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller15)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.074
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           0.000446
# Time:                        13:58:04   Log-Likelihood:                 7277.2
# No. Observations:                3492   AIC:                        -1.454e+04
# Df Residuals:                    3485   BIC:                        -1.450e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.001      0.561      0.575      -0.001       0.002
# Mkt-RF         0.0594      0.052      1.143      0.253      -0.043       0.161
# SMB            0.1143      0.089      1.280      0.201      -0.061       0.289
# HML           -0.1469      0.099     -1.489      0.137      -0.340       0.047
# RMW            0.2049      0.114      1.793      0.073      -0.019       0.429
# CMA           -0.3623      0.144     -2.509      0.012      -0.645      -0.079
# MOM            0.2310      0.193      1.194      0.232      -0.148       0.610
# ==============================================================================
# Omnibus:                      574.932   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11124.567
# Skew:                           0.073   Prob(JB):                         0.00
# Kurtosis:                      11.743   Cond. No.                         379.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.074
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           0.000446
# Time:                        13:58:04   Log-Likelihood:                 7277.2
# No. Observations:                3492   AIC:                        -1.454e+04
# Df Residuals:                    3485   BIC:                        -1.450e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.001      0.561      0.575      -0.001       0.002
# Mkt-RF         0.0594      0.052      1.143      0.253      -0.043       0.161
# SMB            0.1143      0.089      1.280      0.201      -0.061       0.289
# HML           -0.1469      0.099     -1.489      0.137      -0.340       0.047
# RMW            0.2049      0.114      1.793      0.073      -0.019       0.429
# CMA           -0.3623      0.144     -2.509      0.012      -0.645      -0.079
# MOM            0.2310      0.193      1.194      0.232      -0.148       0.610
# ==============================================================================
# Omnibus:                      574.932   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11124.567
# Skew:                           0.073   Prob(JB):                         0.00
# Kurtosis:                      11.743   Cond. No.                         379.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  370  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  3333
#
# There are  370  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  3333
# Number of buy periods 3492
# Check number of buy periods 3492
# Number of sell periods 3492
# Check number of sell periods 3492
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         6.02  6.02
# Ann. Tracking Error                      39.65 39.65
# Ann. Information Ratio (without T-costs)  0.15  0.15
# Skewness of Alpha                        -1.34 -1.34
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       35.66 35.66
# Ann. Volatility                          47.98 47.98
# Ann. Sharpe Ratio (without T-costs)       0.74  0.74
# Skewness of Return                        0.05  0.05
# Average Turnover                          0.14  0.14
# T-costs (on 1 unit of capital)            6.11  6.11

# %%
# 20 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller20)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     5.965
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           3.23e-06
# Time:                        13:58:17   Log-Likelihood:                 8442.6
# No. Observations:                3888   AIC:                        -1.687e+04
# Df Residuals:                    3881   BIC:                        -1.683e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.001      1.121      0.262      -0.001       0.002
# Mkt-RF         0.0888      0.045      1.981      0.048       0.001       0.177
# SMB            0.1032      0.077      1.341      0.180      -0.048       0.254
# HML           -0.1559      0.085     -1.845      0.065      -0.322       0.010
# RMW            0.2340      0.100      2.343      0.019       0.038       0.430
# CMA           -0.3639      0.127     -2.875      0.004      -0.612      -0.116
# MOM            0.1621      0.167      0.969      0.333      -0.166       0.490
# ==============================================================================
# Omnibus:                      498.065   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5029.554
# Skew:                           0.212   Prob(JB):                         0.00
# Kurtosis:                       8.556   Cond. No.                         378.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     5.965
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           3.23e-06
# Time:                        13:58:17   Log-Likelihood:                 8442.6
# No. Observations:                3888   AIC:                        -1.687e+04
# Df Residuals:                    3881   BIC:                        -1.683e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.001      1.121      0.262      -0.001       0.002
# Mkt-RF         0.0888      0.045      1.981      0.048       0.001       0.177
# SMB            0.1032      0.077      1.341      0.180      -0.048       0.254
# HML           -0.1559      0.085     -1.845      0.065      -0.322       0.010
# RMW            0.2340      0.100      2.343      0.019       0.038       0.430
# CMA           -0.3639      0.127     -2.875      0.004      -0.612      -0.116
# MOM            0.1621      0.167      0.969      0.333      -0.166       0.490
# ==============================================================================
# Omnibus:                      498.065   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5029.554
# Skew:                           0.212   Prob(JB):                         0.00
# Kurtosis:                       8.556   Cond. No.                         378.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  369  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  3754
#
# There are  369  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  3754
# Number of buy periods 3888
# Check number of buy periods 3888
# Number of sell periods 3888
# Check number of sell periods 3888
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         9.75  9.75
# Ann. Tracking Error                      35.51 35.51
# Ann. Information Ratio (without T-costs)  0.27  0.27
# Skewness of Alpha                        -0.53 -0.53
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       38.95 38.95
# Ann. Volatility                          44.00 44.00
# Ann. Sharpe Ratio (without T-costs)       0.89  0.89
# Skewness of Return                        0.19  0.19
# Average Turnover                          0.11  0.11
# T-costs (on 1 unit of capital)            8.77  8.77
