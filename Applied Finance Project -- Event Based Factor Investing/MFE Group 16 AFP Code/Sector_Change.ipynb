# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime

import ConstructPortfolio as cp #this will allow us to modularize the code!
#using "ConstructPortfolio.py" that is stored in the same directory! 
#(not using "ConstructPortfolio.ipynb")
# Out:
# /Users/bardiafarajnejad/Desktop/1st Half MFE/AFP/Final Delivery/MFE Group 16 AFP Code

# %%
#### Please run the line below once in order to get "data_with_rets.pkl" from "afp_data_sample_1995_onward_v2.csv"
#cp.get_data(flag=True)

data = pd.read_pickle('data_with_rets.pkl')
data.head()
# Out:
#    tradedate   osid symbol                    coname  sector_group    max_dt  \
# 0   19950103  10032    ACK  Armstrong Holdings Inc             7.0  19970827
# 1   19950104  10032    ACK  Armstrong Holdings Inc             7.0  19970827
# 2   19950105  10032    ACK  Armstrong Holdings Inc             7.0  19970827
# 3   19950106  10032    ACK  Armstrong Holdings Inc             7.0  19970827
# 4   19950109  10032    ACK  Armstrong Holdings Inc             7.0  19970827
#
#    previoustradedate  tickssinceipo     alpha  stdev_alpha  ...  ret1d_lag  \
# 0         19941230.0           8056  0.010006     0.004670  ...    0.00000
# 1         19950103.0           8057 -0.003112     0.004656  ...    0.01929
# 2         19950104.0           8058  0.019820     0.005805  ...    0.04732
# 3         19950105.0           8059  0.045571     0.009709  ...    0.03313
# 4         19950106.0           8060  0.032296     0.010892  ...    0.06706
#
#    alpha1d_lag  ret5d_lag  alpha5d_lag  ret10d_lag  alpha10d_lag  ret15d_lag  \
# 0    -0.003112   0.176850     0.166677    0.131841      0.102035    0.144700
# 1     0.019820   0.131835     0.124719    0.125412      0.099894    0.173638
# 2     0.045571   0.119876     0.112258    0.094651      0.075155    0.170357
# 3     0.032296   0.069278     0.054748    0.063264      0.050293    0.096391
# 4     0.063220   0.058317     0.037605    0.020420      0.006697    0.046651
#
#    alpha15d_lag  ret20d_lag  alpha20d_lag
# 0      0.123317    0.138261      0.106187
# 1      0.151438    0.144692      0.115932
# 2      0.145504    0.135652      0.101416
# 3      0.070299    0.090370      0.047479
# 4      0.026290    0.072892      0.026535
#
# [5 rows x 175 columns]

# %%
#define event using indicator for buy and sell:
data = data.sort_values(['osid', 'tradedate']).reset_index(drop=True).copy()

data = data.loc[data['sector_group'].notna(),:].reset_index(drop=True).copy()
#data = data.loc[data['numpricetargetsraised'].notna(),:].reset_index(drop=True).copy()
#data = data.loc[data['numpricetargetslowered'].notna(),:].reset_index(drop=True).copy()


data['buy_tomorrow'] = np.where(data['sector_group'].diff(1)!= 0, 1, 0)
data['sell_tomorrow'] = np.where(data['sector_group'].diff(1) == 0 , 1, 0)
#df['total_assets'].diff(1)

print('Total number of Buys: ',np.count_nonzero(data['buy_tomorrow']))
print('Total number of Sells: ',np.count_nonzero(data['sell_tomorrow']))

print('Unique buy_tomorrow values: ',np.unique(data['buy_tomorrow'])) #there are only 0 or 1 values in 'buy_tomorrow'
print('Unique sell_tomorrow values: ',np.unique(data['sell_tomorrow'])) #there are only 0 or 1 values in 'sell_tomorrow'
# Out:
# Total number of Buys:  1077
# Total number of Sells:  2797333
# Unique buy_tomorrow values:  [0 1]
# Unique sell_tomorrow values:  [0 1]

# %%
data = cp.trade_on_valid_lags_only(data)
# Out:
# There are  2  problems for buying
#
# There are  570  problems for selling
# Total number of Buys:  1075
# Total number of Sells:  2796763

# %% [markdown]
# # Now we can trade!
# ### Holding period of 1 week, 2 weeks, 3 weeks, and 4 weeks with equal weighted portfolios!

# %%
data_smaller,data_smaller5,data_smaller10,data_smaller15,data_smaller20 = cp.pull_signal_forward(data)

data_smaller20 = cp.trade_on_valid_lags_only(data_smaller20)
data_smaller15 = cp.trade_on_valid_lags_only(data_smaller15)
data_smaller10 = cp.trade_on_valid_lags_only(data_smaller10)
data_smaller5 = cp.trade_on_valid_lags_only(data_smaller5)
data_smaller = cp.trade_on_valid_lags_only(data_smaller)
# Out:
# There are  5  problems for buying
#
# There are  564  problems for selling
# Total number of Buys:  15968
# Total number of Sells:  2794765
#
# There are  5  problems for buying
#
# There are  564  problems for selling
# Total number of Buys:  12284
# Total number of Sells:  2794765
#
# There are  4  problems for buying
#
# There are  564  problems for selling
# Total number of Buys:  8394
# Total number of Sells:  2794765
#
# There are  3  problems for buying
#
# There are  564  problems for selling
# Total number of Buys:  4336
# Total number of Sells:  2794765
#
# There are  0  problems for buying
#
# There are  98  problems for selling
# Total number of Buys:  958
# Total number of Sells:  2794545

# %% [markdown]
# # First, do 1 day holding period: data_smaller
# # Next, do 5 day holding period: data_smaller5
# # Next, do 10 day holding period: data_smaller10
# # Next, do 15 day holding period: data_smaller15
# # Next, do 20 day holding period: data_smaller20

# %%
# 1 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.5249
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):              0.789
# Time:                        13:53:20   Log-Likelihood:                 655.72
# No. Observations:                 430   AIC:                            -1297.
# Df Residuals:                     423   BIC:                            -1269.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0014      0.004     -0.331      0.741      -0.010       0.007
# Mkt-RF         0.0790      0.291      0.271      0.786      -0.493       0.651
# SMB            0.2851      0.480      0.594      0.553      -0.659       1.229
# HML           -0.0623      0.435     -0.143      0.886      -0.918       0.794
# RMW           -0.1755      0.720     -0.244      0.808      -1.592       1.241
# CMA           -0.7913      0.801     -0.988      0.324      -2.365       0.783
# MOM            0.9067      1.003      0.904      0.367      -1.066       2.879
# ==============================================================================
# Omnibus:                      115.284   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              597.562
# Skew:                           1.047   Prob(JB):                    1.74e-130
# Kurtosis:                       8.382   Cond. No.                         394.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.585
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           2.54e-09
# Time:                        13:53:20   Log-Likelihood:                 18216.
# No. Observations:                6715   AIC:                        -3.642e+04
# Df Residuals:                    6708   BIC:                        -3.637e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.255      0.210      -0.000       0.001
# Mkt-RF        -0.0385      0.018     -2.119      0.034      -0.074      -0.003
# SMB            0.0839      0.033      2.523      0.012       0.019       0.149
# HML           -0.0770      0.032     -2.391      0.017      -0.140      -0.014
# RMW           -0.0316      0.045     -0.706      0.480      -0.119       0.056
# CMA           -0.2120      0.057     -3.747      0.000      -0.323      -0.101
# MOM            0.1627      0.073      2.233      0.026       0.020       0.306
# ==============================================================================
# Omnibus:                      801.490   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8412.870
# Skew:                          -0.068   Prob(JB):                         0.00
# Kurtosis:                       8.482   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  131  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  5
#
# There are  1484  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 430
# Check number of buy periods 430
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         3.14  4.59
# Ann. Tracking Error                      78.43 11.84
# Ann. Information Ratio (without T-costs)  0.04  0.39
# Skewness of Alpha                         0.61 -0.31
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       47.58 27.01
# Ann. Volatility                          84.02 25.59
# Ann. Sharpe Ratio (without T-costs)       0.57  1.06
# Skewness of Return                        1.09 -0.10
# Average Turnover                          0.99  0.02
# T-costs (on 1 unit of capital)            0.78  6.98

# %%
# 5 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller5)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.794
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):             0.0967
# Time:                        13:54:48   Log-Likelihood:                 2710.3
# No. Observations:                1566   AIC:                            -5407.
# Df Residuals:                    1559   BIC:                            -5369.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0038      0.002      2.113      0.035       0.000       0.007
# Mkt-RF         0.1361      0.117      1.165      0.244      -0.093       0.365
# SMB            0.0564      0.194      0.290      0.772      -0.324       0.437
# HML           -0.2590      0.202     -1.284      0.199      -0.655       0.137
# RMW            0.1113      0.292      0.381      0.703      -0.462       0.685
# CMA           -0.3958      0.341     -1.160      0.246      -1.065       0.274
# MOM           -0.3312      0.426     -0.777      0.437      -1.167       0.505
# ==============================================================================
# Omnibus:                      313.432   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1502.568
# Skew:                           0.861   Prob(JB):                         0.00
# Kurtosis:                       7.479   Cond. No.                         393.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.587
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           2.53e-09
# Time:                        13:54:48   Log-Likelihood:                 18216.
# No. Observations:                6715   AIC:                        -3.642e+04
# Df Residuals:                    6708   BIC:                        -3.637e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.254      0.210      -0.000       0.001
# Mkt-RF        -0.0385      0.018     -2.119      0.034      -0.074      -0.003
# SMB            0.0839      0.033      2.524      0.012       0.019       0.149
# HML           -0.0770      0.032     -2.391      0.017      -0.140      -0.014
# RMW           -0.0316      0.045     -0.706      0.480      -0.119       0.056
# CMA           -0.2120      0.057     -3.747      0.000      -0.323      -0.101
# MOM            0.1627      0.073      2.233      0.026       0.020       0.306
# ==============================================================================
# Omnibus:                      801.491   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8412.974
# Skew:                          -0.068   Prob(JB):                         0.00
# Kurtosis:                       8.482   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  135  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  1231
#
# There are  1484  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 1566
# Check number of buy periods 1566
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        33.95  4.59
# Ann. Tracking Error                      64.35 11.84
# Ann. Information Ratio (without T-costs)  0.53  0.39
# Skewness of Alpha                         0.53 -0.31
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       72.21 27.00
# Ann. Volatility                          68.31 25.59
# Ann. Sharpe Ratio (without T-costs)       1.06  1.06
# Skewness of Return                        0.84 -0.10
# Average Turnover                          0.30  0.02
# T-costs (on 1 unit of capital)            2.71  6.95

# %%
# 10 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller10)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     4.371
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           0.000213
# Time:                        13:56:11   Log-Likelihood:                 4486.6
# No. Observations:                2459   AIC:                            -8959.
# Df Residuals:                    2452   BIC:                            -8918.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      1.696      0.090      -0.000       0.005
# Mkt-RF         0.1560      0.078      2.012      0.044       0.004       0.308
# SMB            0.0439      0.136      0.322      0.748      -0.223       0.311
# HML           -0.2565      0.140     -1.837      0.066      -0.530       0.017
# RMW            0.0465      0.201      0.232      0.817      -0.347       0.440
# CMA           -0.4403      0.239     -1.841      0.066      -0.909       0.029
# MOM            0.2101      0.307      0.684      0.494      -0.393       0.813
# ==============================================================================
# Omnibus:                      404.389   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2140.836
# Skew:                           0.673   Prob(JB):                         0.00
# Kurtosis:                       7.368   Cond. No.                         390.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.587
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           2.53e-09
# Time:                        13:56:11   Log-Likelihood:                 18216.
# No. Observations:                6715   AIC:                        -3.642e+04
# Df Residuals:                    6708   BIC:                        -3.637e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.254      0.210      -0.000       0.001
# Mkt-RF        -0.0385      0.018     -2.119      0.034      -0.074      -0.003
# SMB            0.0839      0.033      2.524      0.012       0.019       0.149
# HML           -0.0770      0.032     -2.391      0.017      -0.140      -0.014
# RMW           -0.0316      0.045     -0.706      0.480      -0.119       0.056
# CMA           -0.2120      0.057     -3.747      0.000      -0.323      -0.101
# MOM            0.1627      0.073      2.233      0.026       0.020       0.306
# ==============================================================================
# Omnibus:                      801.491   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8412.974
# Skew:                          -0.068   Prob(JB):                         0.00
# Kurtosis:                       8.482   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  138  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  2201
#
# There are  1484  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 2459
# Check number of buy periods 2459
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        43.39  4.59
# Ann. Tracking Error                      58.40 11.84
# Ann. Information Ratio (without T-costs)  0.74  0.39
# Skewness of Alpha                         0.43 -0.31
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       79.81 27.00
# Ann. Volatility                          62.30 25.59
# Ann. Sharpe Ratio (without T-costs)       1.28  1.06
# Skewness of Return                        0.68 -0.10
# Average Turnover                          0.18  0.02
# T-costs (on 1 unit of capital)           11.53  6.95

# %%
# 15 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller15)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     5.252
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           2.15e-05
# Time:                        13:57:28   Log-Likelihood:                 5760.1
# No. Observations:                3082   AIC:                        -1.151e+04
# Df Residuals:                    3075   BIC:                        -1.146e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.001      2.308      0.021       0.000       0.005
# Mkt-RF         0.0953      0.064      1.498      0.134      -0.029       0.220
# SMB            0.0496      0.115      0.431      0.667      -0.176       0.275
# HML           -0.1881      0.117     -1.608      0.108      -0.418       0.041
# RMW           -0.0741      0.166     -0.447      0.655      -0.399       0.251
# CMA           -0.4800      0.197     -2.435      0.015      -0.866      -0.094
# MOM            0.2714      0.260      1.042      0.297      -0.239       0.782
# ==============================================================================
# Omnibus:                      498.627   Durbin-Watson:                   1.867
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3192.300
# Skew:                           0.605   Prob(JB):                         0.00
# Kurtosis:                       7.837   Cond. No.                         387.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.587
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           2.53e-09
# Time:                        13:57:28   Log-Likelihood:                 18216.
# No. Observations:                6715   AIC:                        -3.642e+04
# Df Residuals:                    6708   BIC:                        -3.637e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.254      0.210      -0.000       0.001
# Mkt-RF        -0.0385      0.018     -2.119      0.034      -0.074      -0.003
# SMB            0.0839      0.033      2.524      0.012       0.019       0.149
# HML           -0.0770      0.032     -2.391      0.017      -0.140      -0.014
# RMW           -0.0316      0.045     -0.706      0.480      -0.119       0.056
# CMA           -0.2120      0.057     -3.747      0.000      -0.323      -0.101
# MOM            0.1627      0.073      2.233      0.026       0.020       0.306
# ==============================================================================
# Omnibus:                      801.491   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8412.974
# Skew:                          -0.068   Prob(JB):                         0.00
# Kurtosis:                       8.482   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  105  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  2866
#
# There are  1484  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 3082
# Check number of buy periods 3082
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                             Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         56.38  4.59
# Ann. Tracking Error                       55.49 11.84
# Ann. Information Ratio (without T-costs)   1.02  0.39
# Skewness of Alpha                          0.39 -0.31
# --------------------------                   --    --
# Ann. Mean Return (without T-costs)        92.77 27.00
# Ann. Volatility                           59.58 25.59
# Ann. Sharpe Ratio (without T-costs)        1.56  1.06
# Skewness of Return                         0.59 -0.10
# Average Turnover                           0.14  0.02
# T-costs (on 1 unit of capital)           240.91  6.95

# %%
# 20 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller20)
# Out:
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.214
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           0.000312
# Time:                        13:58:31   Log-Likelihood:                 6770.3
# No. Observations:                3537   AIC:                        -1.353e+04
# Df Residuals:                    3530   BIC:                        -1.348e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023      0.001      2.332      0.020       0.000       0.004
# Mkt-RF         0.0179      0.055      0.325      0.745      -0.090       0.126
# SMB            0.0776      0.102      0.759      0.448      -0.123       0.278
# HML           -0.0950      0.101     -0.941      0.347      -0.293       0.103
# RMW           -0.1136      0.145     -0.785      0.433      -0.397       0.170
# CMA           -0.5051      0.176     -2.872      0.004      -0.850      -0.160
# MOM            0.1751      0.231      0.759      0.448      -0.277       0.627
# ==============================================================================
# Omnibus:                      755.370   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7602.125
# Skew:                           0.721   Prob(JB):                         0.00
# Kurtosis:                      10.036   Cond. No.                         384.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.587
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):           2.53e-09
# Time:                        13:58:31   Log-Likelihood:                 18216.
# No. Observations:                6715   AIC:                        -3.642e+04
# Df Residuals:                    6708   BIC:                        -3.637e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.254      0.210      -0.000       0.001
# Mkt-RF        -0.0385      0.018     -2.119      0.034      -0.074      -0.003
# SMB            0.0839      0.033      2.524      0.012       0.019       0.149
# HML           -0.0770      0.032     -2.391      0.017      -0.140      -0.014
# RMW           -0.0316      0.045     -0.706      0.480      -0.119       0.056
# CMA           -0.2120      0.057     -3.747      0.000      -0.323      -0.101
# MOM            0.1627      0.073      2.233      0.026       0.020       0.306
# ==============================================================================
# Omnibus:                      801.491   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8412.974
# Skew:                          -0.068   Prob(JB):                         0.00
# Kurtosis:                       8.482   Cond. No.                         372.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  105  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  3352
#
# There are  1484  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 3537
# Check number of buy periods 3537
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)        41.98  4.59
# Ann. Tracking Error                      52.83 11.84
# Ann. Information Ratio (without T-costs)  0.79  0.39
# Skewness of Alpha                         0.45 -0.31
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       76.50 27.00
# Ann. Volatility                          56.85 25.59
# Ann. Sharpe Ratio (without T-costs)       1.35  1.06
# Skewness of Return                        0.71 -0.10
# Average Turnover                          0.12  0.02
# T-costs (on 1 unit of capital)           98.95  6.95
