# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime

import ConstructPortfolio as cp #this will allow us to modularize the code!
#using "ConstructPortfolio.py" that is stored in the same directory! 
#(not using "ConstructPortfolio.ipynb")
# Out:
# /Users/bardiafarajnejad/Desktop/1st Half MFE/AFP/Final Delivery/MFE Group 16 AFP Code

# %% [markdown]
# # lots of profits when trading on volume spikes in the 1-5 day horizon (When shorting costly or not allowed, high trading volume means optimism and overvaluation, leading to low returns)

# %%
#### Please run the line below once in order to get "data_with_rets.pkl" from "afp_data_sample_1995_onward_v2.csv"
#cp.get_data(flag=True)

data = pd.read_pickle('data_with_rets.pkl')
data
# Out:
#          tradedate   osid symbol                    coname  sector_group  \
# 0         19950103  10032    ACK  Armstrong Holdings Inc             7.0
# 1         19950104  10032    ACK  Armstrong Holdings Inc             7.0
# 2         19950105  10032    ACK  Armstrong Holdings Inc             7.0
# 3         19950106  10032    ACK  Armstrong Holdings Inc             7.0
# 4         19950109  10032    ACK  Armstrong Holdings Inc             7.0
# ...            ...    ...    ...                       ...           ...
# 2912427   20210805  78696   COOK               Traeger Inc           7.0
# 2912428   20210806  78722   WEBR            Weber Inc Cl A           NaN
# 2912429   20210809  78722   WEBR            Weber Inc Cl A           7.0
# 2912430   20210901  78803   FCUV       Focus Universal Inc           NaN
# 2912431   20210902  78803   FCUV       Focus Universal Inc           4.0
#
#            max_dt  previoustradedate  tickssinceipo     alpha  stdev_alpha  \
# 0        19970827         19941230.0           8056  0.010006     0.004670
# 1        19970827         19950103.0           8057 -0.003112     0.004656
# 2        19970827         19950104.0           8058  0.019820     0.005805
# 3        19970827         19950105.0           8059  0.045571     0.009709
# 4        19970827         19950106.0           8060  0.032296     0.010892
# ...           ...                ...            ...       ...          ...
# 2912427  20210805         20210804.0              6  0.047968     0.026349
# 2912428  20210809         20210805.0              2  0.000000     0.000000
# 2912429  20210809         20210806.0              3  0.080042     0.025773
# 2912430  20210902         20210831.0              2  0.000000     0.000000
# 2912431  20210902         20210901.0              3 -0.072293     0.019244
#
#          ...  ret1d_lag  alpha1d_lag  ret5d_lag  alpha5d_lag  ret10d_lag  \
# 0        ...    0.00000    -0.003112   0.176850     0.166677    0.131841
# 1        ...    0.01929     0.019820   0.131835     0.124719    0.125412
# 2        ...    0.04732     0.045571   0.119876     0.112258    0.094651
# 3        ...    0.03313     0.032296   0.069278     0.054748    0.063264
# 4        ...    0.06706     0.063220   0.058317     0.037605    0.020420
# ...      ...        ...          ...        ...          ...         ...
# 2912427  ...        NaN          NaN        NaN          NaN         NaN
# 2912428  ...    0.08190     0.080042        NaN          NaN         NaN
# 2912429  ...        NaN          NaN        NaN          NaN         NaN
# 2912430  ...   -0.07106    -0.072293        NaN          NaN         NaN
# 2912431  ...        NaN          NaN        NaN          NaN         NaN
#
#          alpha10d_lag  ret15d_lag  alpha15d_lag  ret20d_lag  alpha20d_lag
# 0            0.102035    0.144700      0.123317    0.138261      0.106187
# 1            0.099894    0.173638      0.151438    0.144692      0.115932
# 2            0.075155    0.170357      0.145504    0.135652      0.101416
# 3            0.050293    0.096391      0.070299    0.090370      0.047479
# 4            0.006697    0.046651      0.026290    0.072892      0.026535
# ...               ...         ...           ...         ...           ...
# 2912427           NaN         NaN           NaN         NaN           NaN
# 2912428           NaN         NaN           NaN         NaN           NaN
# 2912429           NaN         NaN           NaN         NaN           NaN
# 2912430           NaN         NaN           NaN         NaN           NaN
# 2912431           NaN         NaN           NaN         NaN           NaN
#
# [2912432 rows x 175 columns]

# %% [markdown]
# ### Now, let's trade on the times when volume spikes
# ###### Buy when vol spikes above the 50_day_avgVol --> put a 1 and trade tomorrow
# ###### Sell when vol falls below the 50_day_avgVol --> put a 1 and trade tomorrow
# ### with 1 day, 1 week, 2 weeks, 3 weeks, and 4 weeks holding period
# ### (AHEAD, not backward... so our ret, ret5d, 10d, 15d, and 20d needs to be forward)
# ### Thus, we will use ret5d_'lag' !!
#
# # Set buy_tomorrow>0 when vol spikes above the 50_day_avgVol
# # Set Sell_tomorrow>0 when vol falls below the 50_day_avgVol

# %%
#define event using indicator for buy and sell:
data = data.sort_values(['osid', 'tradedate']).reset_index(drop=True).copy()

data = data.loc[data['volume'].notna(),:].reset_index(drop=True).copy()
data = data.loc[data['avgvol50d'].notna(),:].reset_index(drop=True).copy()

data['buy_tomorrow'] = np.where(data['volume']/data['avgvol50d']>1.25, 1, 0)
data['sell_tomorrow'] = np.where(data['volume']/data['avgvol50d']<0.75, 1, 0)


print('Total number of Buys: ',np.count_nonzero(data['buy_tomorrow']))
print('Total number of Sells: ',np.count_nonzero(data['sell_tomorrow']))

print('Unique buy_tomorrow values: ',np.unique(data['buy_tomorrow'])) #there are only 0 or 1 values in 'buy_tomorrow'
print('Unique sell_tomorrow values: ',np.unique(data['sell_tomorrow'])) #there are only 0 or 1 values in 'sell_tomorrow'
# Out:
# Total number of Buys:  652819
# Total number of Sells:  1207551
# Unique buy_tomorrow values:  [0 1]
# Unique sell_tomorrow values:  [0 1]

# %%
data = cp.trade_on_valid_lags_only(data)
# Out:
# There are  46  problems for buying
#
# There are  27  problems for selling
# Total number of Buys:  652773
# Total number of Sells:  1207524

# %% [markdown]
# # Now we can trade!
# ### Holding period of 1 week, 2 weeks, 3 weeks, and 4 weeks with equal weighted portfolios!
#
# # First, create daily equal weighted portfolio weights and returns (NOT AT THE WEEKLY frequency because that will mess up the implementation of the portfolio!). Problem is:
#
# ##### Think (part 1): 1st signal on Monday- want to buy on Tuesday and hold for 1 week in an equal weighted portfolio
# ##### Think (part 2): 2nd signal on Thursday- want to buy on Friday and hold for 1 week in an equal weighted portfolio
# ##### Think (part 3): Will have overlapping portfolio between 1st and 2nd signal on Friday and on Monday
#
# ## Then, for 1 week, 2 week, 3 week, and 4 week holding periods, we must do the following:
# ##### extend "buy_tomorrow" and "sell_tomorrow" forward for 4 more trading days

# %%
data_smaller,data_smaller5,data_smaller10,data_smaller15,data_smaller20 = cp.pull_signal_forward(data)

data_smaller20 = cp.trade_on_valid_lags_only(data_smaller20)
data_smaller15 = cp.trade_on_valid_lags_only(data_smaller15)
data_smaller10 = cp.trade_on_valid_lags_only(data_smaller10)
data_smaller5 = cp.trade_on_valid_lags_only(data_smaller5)
data_smaller = cp.trade_on_valid_lags_only(data_smaller)
# Out:
# There are  99  problems for buying
#
# There are  108  problems for selling
# Total number of Buys:  2663620
# Total number of Sells:  2847854
#
# There are  97  problems for buying
#
# There are  103  problems for selling
# Total number of Buys:  2497102
# Total number of Sells:  2785081
#
# There are  91  problems for buying
#
# There are  95  problems for selling
# Total number of Buys:  2203105
# Total number of Sells:  2645015
#
# There are  75  problems for buying
#
# There are  77  problems for selling
# Total number of Buys:  1637094
# Total number of Sells:  2279283
#
# There are  38  problems for buying
#
# There are  32  problems for selling
# Total number of Buys:  652294
# Total number of Sells:  1206341

# %% [markdown]
# # First, do 1 day holding period: data_smaller
# # Next, do 5 day holding period: data_smaller5
# # Next, do 10 day holding period: data_smaller10
# # Next, do 15 day holding period: data_smaller15
# # Next, do 20 day holding period: data_smaller20

# %%
# 1 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller)
# Out:
# There are  2  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.524
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):              0.166
# Time:                        18:24:49   Log-Likelihood:                 6273.8
# No. Observations:                6712   AIC:                        -1.253e+04
# Df Residuals:                    6705   BIC:                        -1.249e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.002      0.232      0.816      -0.003       0.004
# Mkt-RF         0.1541      0.108      1.432      0.152      -0.057       0.365
# SMB            0.4064      0.197      2.065      0.039       0.021       0.792
# HML           -0.0387      0.191     -0.203      0.839      -0.412       0.335
# RMW            0.3611      0.265      1.363      0.173      -0.158       0.880
# CMA           -0.1707      0.335     -0.510      0.610      -0.827       0.486
# MOM            0.6541      0.431      1.516      0.129      -0.191       1.500
# ==============================================================================
# Omnibus:                    24682.946   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      11054302979.965
# Skew:                          78.013   Prob(JB):                         0.00
# Kurtosis:                    6288.091   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     9.186
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):           4.84e-10
# Time:                        18:24:49   Log-Likelihood:                 18230.
# No. Observations:                6715   AIC:                        -3.645e+04
# Df Residuals:                    6708   BIC:                        -3.640e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001      0.000     -0.330      0.741      -0.001       0.001
# Mkt-RF        -0.0096      0.018     -0.529      0.597      -0.045       0.026
# SMB            0.0969      0.033      2.920      0.004       0.032       0.162
# HML           -0.0839      0.032     -2.609      0.009      -0.147      -0.021
# RMW           -0.0271      0.045     -0.607      0.544      -0.115       0.060
# CMA           -0.1989      0.056     -3.521      0.000      -0.310      -0.088
# MOM            0.1931      0.073      2.655      0.008       0.051       0.336
# ==============================================================================
# Omnibus:                      838.161   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9133.265
# Skew:                          -0.126   Prob(JB):                         0.00
# Kurtosis:                       8.708   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  210035  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6707
#
# There are  188493  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6711
# Number of buy periods 6712
# Check number of buy periods 6712
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                                Buy  Sell
#
# Ann. Mean Alpha (without T-costs)            20.18 -4.35
# Ann. Tracking Error                          14.52 12.49
# Ann. Information Ratio (without T-costs)      1.39 -0.35
# Skewness of Alpha                            -0.40 -0.34
# --------------------------                      --    --
# Ann. Mean Return (without T-costs)           78.13 16.86
# Ann. Volatility                             150.96 25.54
# Ann. Sharpe Ratio (without T-costs)           0.52  0.66
# Skewness of Return                           78.15 -0.16
# Average Turnover                              0.56  0.41
# T-costs (on 1 unit of capital)           21,981.07  3.47

# %%
# 5 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller5)
# Out:
# There are  3  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  1  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.684
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):              0.121
# Time:                        18:27:05   Log-Likelihood:                 8728.2
# No. Observations:                6715   AIC:                        -1.744e+04
# Df Residuals:                    6708   BIC:                        -1.739e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.842e-05      0.001      0.057      0.954      -0.003       0.003
# Mkt-RF         0.0824      0.075      1.103      0.270      -0.064       0.229
# SMB            0.3039      0.137      2.225      0.026       0.036       0.572
# HML           -0.0635      0.132     -0.480      0.631      -0.323       0.196
# RMW            0.2454      0.184      1.335      0.182      -0.115       0.606
# CMA           -0.1939      0.232     -0.834      0.404      -0.650       0.262
# MOM            0.4993      0.299      1.668      0.095      -0.088       1.086
# ==============================================================================
# Omnibus:                    24343.127   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       9852460298.859
# Skew:                          74.696   Prob(JB):                         0.00
# Kurtosis:                    5935.221   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.598
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):              0.143
# Time:                        18:27:05   Log-Likelihood:                 6669.0
# No. Observations:                6715   AIC:                        -1.332e+04
# Df Residuals:                    6708   BIC:                        -1.328e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.002     -0.278      0.781      -0.004       0.003
# Mkt-RF         0.1406      0.102      1.385      0.166      -0.058       0.340
# SMB            0.3874      0.186      2.088      0.037       0.024       0.751
# HML           -0.0641      0.180     -0.356      0.722      -0.417       0.288
# RMW            0.3258      0.250      1.304      0.192      -0.164       0.815
# CMA           -0.1896      0.316     -0.600      0.548      -0.809       0.430
# MOM            0.6621      0.407      1.628      0.104      -0.135       1.460
# ==============================================================================
# Omnibus:                    24691.566   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      11054018864.383
# Skew:                          77.990   Prob(JB):                         0.00
# Kurtosis:                    6286.606   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  109721  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
#
# There are  67791  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 6715
# Check number of buy periods 6715
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                             Buy   Sell
#
# Ann. Mean Alpha (without T-costs)          8.24   3.91
# Ann. Tracking Error                       12.12  11.91
# Ann. Information Ratio (without T-costs)   0.68   0.33
# Skewness of Alpha                         -0.26  -0.31
# --------------------------                   --     --
# Ann. Mean Return (without T-costs)        52.62  53.87
# Ann. Volatility                          104.79 142.39
# Ann. Sharpe Ratio (without T-costs)        0.50   0.38
# Skewness of Return                        74.80  78.11
# Average Turnover                           0.14   0.09
# T-costs (on 1 unit of capital)           941.91 225.95

# %%
# 10 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller10)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.985
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0642
# Time:                        18:29:49   Log-Likelihood:                 10558.
# No. Observations:                6715   AIC:                        -2.110e+04
# Df Residuals:                    6708   BIC:                        -2.105e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        5.27e-05      0.001      0.050      0.960      -0.002       0.002
# Mkt-RF         0.0496      0.057      0.873      0.383      -0.062       0.161
# SMB            0.2448      0.104      2.354      0.019       0.041       0.449
# HML           -0.0697      0.101     -0.692      0.489      -0.267       0.128
# RMW            0.1679      0.140      1.200      0.230      -0.106       0.442
# CMA           -0.1938      0.177     -1.095      0.274      -0.541       0.153
# MOM            0.4261      0.228      1.869      0.062      -0.021       0.873
# ==============================================================================
# Omnibus:                    23792.790   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       8200847674.471
# Skew:                          69.728   Prob(JB):                         0.00
# Kurtosis:                    5415.125   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.543
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):              0.160
# Time:                        18:29:49   Log-Likelihood:                 6990.2
# No. Observations:                6715   AIC:                        -1.397e+04
# Df Residuals:                    6708   BIC:                        -1.392e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.229      0.819      -0.004       0.003
# Mkt-RF         0.1225      0.097      1.266      0.206      -0.067       0.312
# SMB            0.3661      0.177      2.069      0.039       0.019       0.713
# HML           -0.0623      0.171     -0.363      0.716      -0.398       0.274
# RMW            0.3105      0.238      1.304      0.192      -0.156       0.777
# CMA           -0.1909      0.301     -0.634      0.526      -0.781       0.399
# MOM            0.6334      0.388      1.633      0.102      -0.127       1.394
# ==============================================================================
# Omnibus:                    24647.964   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      10896483702.230
# Skew:                          77.572   Prob(JB):                         0.00
# Kurtosis:                    6241.663   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  57611  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
#
# There are  27194  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 6715
# Check number of buy periods 6715
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                             Buy   Sell
#
# Ann. Mean Alpha (without T-costs)          6.01   4.77
# Ann. Tracking Error                       11.88  11.81
# Ann. Information Ratio (without T-costs)   0.51   0.40
# Skewness of Alpha                         -0.28  -0.31
# --------------------------                   --     --
# Ann. Mean Return (without T-costs)        44.39  53.70
# Ann. Volatility                           79.81 135.74
# Ann. Sharpe Ratio (without T-costs)        0.56   0.40
# Skewness of Return                        69.79  77.69
# Average Turnover                           0.07   0.04
# T-costs (on 1 unit of capital)           244.77 160.24

# %%
# 15 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller15)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.023
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0591
# Time:                        18:33:34   Log-Likelihood:                 10684.
# No. Observations:                6715   AIC:                        -2.135e+04
# Df Residuals:                    6708   BIC:                        -2.131e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.716e-05      0.001      0.017      0.987      -0.002       0.002
# Mkt-RF         0.0477      0.056      0.854      0.393      -0.062       0.157
# SMB            0.2414      0.102      2.366      0.018       0.041       0.442
# HML           -0.0689      0.099     -0.697      0.486      -0.263       0.125
# RMW            0.1607      0.137      1.169      0.242      -0.109       0.430
# CMA           -0.1954      0.174     -1.125      0.261      -0.536       0.145
# MOM            0.4236      0.224      1.893      0.058      -0.015       0.862
# ==============================================================================
# Omnibus:                    23740.323   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       8057775741.969
# Skew:                          69.269   Prob(JB):                         0.00
# Kurtosis:                    5367.700   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.717
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):              0.113
# Time:                        18:33:34   Log-Likelihood:                 8931.5
# No. Observations:                6715   AIC:                        -1.785e+04
# Df Residuals:                    6708   BIC:                        -1.780e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.001     -0.124      0.901      -0.003       0.002
# Mkt-RF         0.0742      0.072      1.024      0.306      -0.068       0.216
# SMB            0.2919      0.132      2.203      0.028       0.032       0.552
# HML           -0.0678      0.128     -0.528      0.597      -0.319       0.184
# RMW            0.2145      0.178      1.203      0.229      -0.135       0.564
# CMA           -0.1990      0.226     -0.883      0.377      -0.641       0.243
# MOM            0.5106      0.290      1.758      0.079      -0.059       1.080
# ==============================================================================
# Omnibus:                    24299.441   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       9710872584.607
# Skew:                          74.292   Prob(JB):                         0.00
# Kurtosis:                    5892.434   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  33091  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
#
# There are  12591  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 6715
# Check number of buy periods 6715
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                             Buy   Sell
#
# Ann. Mean Alpha (without T-costs)          5.42   5.07
# Ann. Tracking Error                       11.82  11.82
# Ann. Information Ratio (without T-costs)   0.46   0.43
# Skewness of Alpha                         -0.30  -0.26
# --------------------------                   --     --
# Ann. Mean Return (without T-costs)        43.19  47.30
# Ann. Volatility                           78.32 101.67
# Ann. Sharpe Ratio (without T-costs)        0.55   0.47
# Skewness of Return                        69.33  74.38
# Average Turnover                           0.04   0.03
# T-costs (on 1 unit of capital)           130.84  89.61

# %%
# 20 day holding period
cp.get_returns_turnover_Tcost_summary_plusPlots(data_smaller20)
# Out:
# There are  0  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# There are  3  returns that dont match using .mean() vs. using equal weights
#
# There are  0  alphas that dont match using .mean() vs. using equal weights
#
# All weights sum to one for Buys
#
# All weights sum to one for Sells
# Regression for Buy Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.052
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0555
# Time:                        18:37:56   Log-Likelihood:                 10824.
# No. Observations:                6715   AIC:                        -2.163e+04
# Df Residuals:                    6708   BIC:                        -2.159e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.854e-05      0.001      0.018      0.985      -0.002       0.002
# Mkt-RF         0.0462      0.055      0.846      0.398      -0.061       0.153
# SMB            0.2371      0.100      2.372      0.018       0.041       0.433
# HML           -0.0683      0.097     -0.705      0.481      -0.258       0.122
# RMW            0.1555      0.135      1.156      0.248      -0.108       0.419
# CMA           -0.1969      0.170     -1.158      0.247      -0.530       0.137
# MOM            0.4160      0.219      1.899      0.058      -0.014       0.846
# ==============================================================================
# Omnibus:                    23679.260   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       7894163297.948
# Skew:                          68.738   Prob(JB):                         0.00
# Kurtosis:                    5312.947   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Regression for Sell Portfolio
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ew_return-RF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.837
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):             0.0880
# Time:                        18:37:56   Log-Likelihood:                 9569.0
# No. Observations:                6715   AIC:                        -1.912e+04
# Df Residuals:                    6708   BIC:                        -1.908e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001      0.001     -0.085      0.932      -0.002       0.002
# Mkt-RF         0.0664      0.066      1.007      0.314      -0.063       0.196
# SMB            0.2734      0.120      2.269      0.023       0.037       0.510
# HML           -0.0667      0.117     -0.572      0.568      -0.296       0.162
# RMW            0.1931      0.162      1.191      0.234      -0.125       0.511
# CMA           -0.2003      0.205     -0.977      0.329      -0.602       0.202
# MOM            0.4751      0.264      1.799      0.072      -0.043       0.993
# ==============================================================================
# Omnibus:                    24131.925   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       9185049242.804
# Skew:                          72.756   Prob(JB):                         0.00
# Kurtosis:                    5730.739   Cond. No.                         372.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# There are  19543  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
#
# There are  6414  problems for turnover using lag_weight_in_portfolio_end
# Total number of days when turnover is not equal to 100%:  6713
# Number of buy periods 6715
# Check number of buy periods 6715
# Number of sell periods 6715
# Check number of sell periods 6715
# Summary Statistics:
#
#                                            Buy  Sell
#
# Ann. Mean Alpha (without T-costs)         5.15  4.97
# Ann. Tracking Error                      11.80 11.79
# Ann. Information Ratio (without T-costs)  0.44  0.42
# Skewness of Alpha                        -0.32 -0.31
# --------------------------                  --    --
# Ann. Mean Return (without T-costs)       42.48 45.35
# Ann. Volatility                          76.71 92.46
# Ann. Sharpe Ratio (without T-costs)       0.55  0.49
# Skewness of Return                       68.80 72.84
# Average Turnover                          0.03  0.02
# T-costs (on 1 unit of capital)           85.63 64.60
